# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# False
# 0
# No GPU found

# %% [markdown]
# ## Retransfrom csv files form str

# %%
import os
from src.utils.format_helpers import convert_str_to_csv

def batch_convert_str_to_csv(directory):
    """Convert all .str files in a specified directory to CSV without modifying the original .str files."""
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.str'):
                str_file = os.path.join(root, file)
                str_dir = os.path.dirname(str_file)

                # Here the base_input_directory is 'results' as we already perfrom the transcription in the 'results' folder 
                # (.str files are in 'results' folder)
                base_input_directory = 'results'
                relative_path = os.path.relpath(str_file, base_input_directory)  
                experiment_name = relative_path.split(os.sep)[0]  # Extract the first folder in 'relative_path'
                print("Directory: ", str_dir)
                print("Experiment: ", experiment_name)
                convert_str_to_csv(str_file, experiment_name)
                print(f"Finished converting {str_file}.")

# %%
# Specify the directory containing .str files
directory = 'results'
batch_convert_str_to_csv(directory)
# Out:
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S301final.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S302con.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S302man.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S303con.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S303man.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S304.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S305con.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S306.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S307.str.
# Directory:  results\Compassion
# Experiment:  Compassion
# Finished converting results\Compassion\S313.str.
# Directory:  results\Grief\eng\ADE_pilot_003
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_003\ADE_pilot_003_interview_04.10.24_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_003
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_003\ADE_pilot_003_interview_04.10.24_part2.str.
# Directory:  results\Grief\eng\ADE_pilot_004
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_004\ADE_pilot_004_interview_15.10.24_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_004
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_004\ADE_pilot_004_interview_15.10.24_part2.str.
# Directory:  results\Grief\eng\ADE_pilot_005
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_005\ADE_pilot_005_interview_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_005
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_005\ADE_pilot_005_interview_part2.str.
# Directory:  results\Grief\eng\ADE_pilot_006
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_006\ADE_pilot_006_interview_30.10.24_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_006
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_006\ADE_pilot_006_interview_30.10.24_part2.str.
# Directory:  results\Grief\eng\ADE_pilot_007
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_007\ADE_pilot_007_interview_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_007
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_007\ADE_pilot_007_interview_part2.str.
# Directory:  results\Grief\eng\ADE_pilot_008
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_008\ADE_pilot_008_interview_05.11.24_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_008
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_008\ADE_pilot_008_interview_05.11.24_part2.str.
# Directory:  results\Grief\eng\ADE_pilot_009
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_009\ADE_pilot_009_interview_08.11.24_part1.str.
# Directory:  results\Grief\eng\ADE_pilot_009
# Experiment:  Grief
# Finished converting results\Grief\eng\ADE_pilot_009\ADE_pilot_009_interview_08.11.24_part2.str.
# Directory:  results\Grief\french\fr\ADE_pilot_002
# Experiment:  Grief
# Finished converting results\Grief\french\fr\ADE_pilot_002\ADE_pilot_002_interview_08.10.24_part1.str.
# Directory:  results\Grief\french\fr\ADE_pilot_002
# Experiment:  Grief
# Finished converting results\Grief\french\fr\ADE_pilot_002\ADE_pilot_002_interview_08.10.24_part2.str.
# Directory:  results\Grief\french\fr_to_eng\ADE_pilot_002
# Experiment:  Grief
# Finished converting results\Grief\french\fr_to_eng\ADE_pilot_002\ADE_pilot_002_interview_08.10.24_part1.str.
# Directory:  results\Grief\french\fr_to_eng\ADE_pilot_002
# Experiment:  Grief
# Finished converting results\Grief\french\fr_to_eng\ADE_pilot_002\ADE_pilot_002_interview_08.10.24_part2.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\ID 05.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 08.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 13.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 13b.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 14.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 15.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 16.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 17.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 18.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 19.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 19b.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 22.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 23.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 24.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 24b.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 7a.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Id 7b.str.
# Directory:  results\OBE1
# Experiment:  OBE1
# Finished converting results\OBE1\Participant 20 interview.str.
# Directory:  results\OBE2\S201
# Experiment:  OBE2
# Finished converting results\OBE2\S201\S201-1.str.
# Directory:  results\OBE2\S201
# Experiment:  OBE2
# Finished converting results\OBE2\S201\S201-2.str.
# Directory:  results\OBE2\S201
# Experiment:  OBE2
# Finished converting results\OBE2\S201\S201-3.str.
# Directory:  results\OBE2\S202
# Experiment:  OBE2
# Finished converting results\OBE2\S202\S202-1.str.
# Directory:  results\OBE2\S203
# Experiment:  OBE2
# Finished converting results\OBE2\S203\S203-1.str.
# Directory:  results\OBE2\S204
# Experiment:  OBE2
# Finished converting results\OBE2\S204\S204-1.str.
# Directory:  results\OBE2\S204
# Experiment:  OBE2
# Finished converting results\OBE2\S204\S204-2.str.
# Directory:  results\OBE2\S205
# Experiment:  OBE2
# Finished converting results\OBE2\S205\S205-1.str.
# Directory:  results\OBE2\S205
# Experiment:  OBE2
# Finished converting results\OBE2\S205\S205-2.str.
# Directory:  results\OBE2\S206
# Experiment:  OBE2
# Finished converting results\OBE2\S206\S206-1.str.
# Directory:  results\OBE2\S206
# Experiment:  OBE2
# Finished converting results\OBE2\S206\S206-2.str.
# Directory:  results\OBE2\S207
# Experiment:  OBE2
# Finished converting results\OBE2\S207\S207-1.str.
# Directory:  results\OBE2\S207
# Experiment:  OBE2
# Finished converting results\OBE2\S207\S207-2.str.
# Directory:  results\OBE2\S208
# Experiment:  OBE2
# Finished converting results\OBE2\S208\S208-1.str.
# Directory:  results\OBE2\S208
# Experiment:  OBE2
# Finished converting results\OBE2\S208\S208-2.str.
# Directory:  results\OBE2\S209
# Experiment:  OBE2
# Finished converting results\OBE2\S209\S209-1.str.
# Directory:  results\OBE2\S209
# Experiment:  OBE2
# Finished converting results\OBE2\S209\S209-2.str.
# Directory:  results\OBE2\S209
# Experiment:  OBE2
# Finished converting results\OBE2\S209\S209-3.str.
# Directory:  results\OBE2\S209
# Experiment:  OBE2
# Finished converting results\OBE2\S209\S209-4.str.
# Directory:  results\OBE2\S210
# Experiment:  OBE2
# Finished converting results\OBE2\S210\S210-1.str.
# Directory:  results\OBE2\S210
# Experiment:  OBE2
# Finished converting results\OBE2\S210\S210-2.str.
# Directory:  results\OBE2\S210
# Experiment:  OBE2
# Finished converting results\OBE2\S210\S210-3.str.
# Directory:  results\OBE2\S211
# Experiment:  OBE2
# Finished converting results\OBE2\S211\S211_1.str.
# Directory:  results\OBE2\S211
# Experiment:  OBE2
# Finished converting results\OBE2\S211\S211_2.str.
# Directory:  results\OBE2\S211
# Experiment:  OBE2
# Finished converting results\OBE2\S211\S211_3 (partially in french).str.
# Directory:  results\OBE2\S212
# Experiment:  OBE2
# Finished converting results\OBE2\S212\S212_1.str.
# Directory:  results\OBE2\S212
# Experiment:  OBE2
# Finished converting results\OBE2\S212\S212_2.str.
# Directory:  results\OBE2\S213
# Experiment:  OBE2
# Finished converting results\OBE2\S213\S213_1.str.
# Directory:  results\OBE2\S213
# Experiment:  OBE2
# Finished converting results\OBE2\S213\S213_2.str.
# Directory:  results\OBE2\S214
# Experiment:  OBE2
# Finished converting results\OBE2\S214\S214_1.str.
# Directory:  results\OBE2\S214
# Experiment:  OBE2
# Finished converting results\OBE2\S214\S214_2.str.
# Directory:  results\OBE2\S217
# Experiment:  OBE2
# Finished converting results\OBE2\S217\S217.str.
# Directory:  results\OBE2\S218
# Experiment:  OBE2
# Finished converting results\OBE2\S218\S218-1.str.
# Directory:  results\OBE2\S218
# Experiment:  OBE2
# Finished converting results\OBE2\S218\S218-2.str.
# Directory:  results\OBE2\S219
# Experiment:  OBE2
# Finished converting results\OBE2\S219\S219-1.str.
# Directory:  results\OBE2\S219
# Experiment:  OBE2
# Finished converting results\OBE2\S219\S219-2.str.
# Directory:  results\OBE2\S220
# Experiment:  OBE2
# Finished converting results\OBE2\S220\S220-1.str.
# Directory:  results\OBE2\S220
# Experiment:  OBE2
# Finished converting results\OBE2\S220\S220-2.str.
# Directory:  results\OBE2\S222
# Experiment:  OBE2
# Finished converting results\OBE2\S222\S222_c.str.
# Directory:  results\OBE2\S222
# Experiment:  OBE2
# Finished converting results\OBE2\S222\S222_m.str.
# Directory:  results\OBE2\S223
# Experiment:  OBE2
# Finished converting results\OBE2\S223\S223.str.
# Directory:  results\OBE2\S225
# Experiment:  OBE2
# Finished converting results\OBE2\S225\S225.str.
# Directory:  results\OBE2\S225
# Experiment:  OBE2
# Finished converting results\OBE2\S225\S225[1].str.
# Directory:  results\OBE2\S226
# Experiment:  OBE2
# Finished converting results\OBE2\S226\S226.str.
# Directory:  results\OBE2\S226
# Experiment:  OBE2
# Finished converting results\OBE2\S226\S226[1].str.
# Directory:  results\OBE2\S226
# Experiment:  OBE2
# Finished converting results\OBE2\S226\S226[2].str.
# Directory:  results\OBE2\S227
# Experiment:  OBE2
# Finished converting results\OBE2\S227\S227 control interview.str.
# Directory:  results\OBE2\S227
# Experiment:  OBE2
# Finished converting results\OBE2\S227\S227 intervention.str.
# Directory:  results\OBE2\S228
# Experiment:  OBE2
# Finished converting results\OBE2\S228\S228 control.str.
# Directory:  results\OBE2\S228
# Experiment:  OBE2
# Finished converting results\OBE2\S228\S228 intervention.str.
# Directory:  results\OBE2\S229
# Experiment:  OBE2
# Finished converting results\OBE2\S229\S229 control.str.
# Directory:  results\OBE2\S229
# Experiment:  OBE2
# Finished converting results\OBE2\S229\S229 intervention.str.
# Directory:  results\OBE2\S230
# Experiment:  OBE2
# Finished converting results\OBE2\S230\S230 control.str.
# Directory:  results\OBE2\S230
# Experiment:  OBE2
# Finished converting results\OBE2\S230\S230 intervention.str.

# %%
import os
import pandas as pd

def add_missing_column_recursive(folder_path, new_column_name, new_column_value, insert_position):
    """
    Recursively adds a missing column to all CSV files in a folder and its subfolders.

    Parameters:
        folder_path (str): Path to the folder containing the CSV files.
        new_column_name (str): Name of the new column to be added.
        new_column_value (str): Default value for the new column.
        insert_position (int): Index where the new column should be inserted.
    """
    for root, _, files in os.walk(folder_path):
        for file_name in files:
            if file_name.endswith(".csv"):
                file_path = os.path.join(root, file_name)
                
                # Read the CSV file
                try:
                    df = pd.read_csv(file_path)
                except Exception as e:
                    print(f"Error reading file {file_path}: {e}")
                    continue
                
                # Check if the column already exists
                if new_column_name not in df.columns:
                    # Insert the new column at the specified position
                    df.insert(insert_position, new_column_name, new_column_value)
                    
                    # Save the updated CSV back to the file
                    try:
                        df.to_csv(file_path, index=False)
                        print(f"Updated file: {file_path}")
                    except Exception as e:
                        print(f"Error saving file {file_path}: {e}")
                else:
                    print(f"Column '{new_column_name}' already exists in {file_path}")

# Example Usage
#folder_path = "Reports/meditations_transcripts"  # Replace with your folder path
#add_missing_column_recursive(folder_path, new_column_name="Content Type", new_column_value="Audio", insert_position=3)
# Out:
# Updated file: Reports/meditations_transcripts\overview_interviews.csv
# Updated file: Reports/meditations_transcripts\transcripts_merged.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S301final.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S302con.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S302man.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S303con.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S303man.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S304.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S305con.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S306.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S307.csv
# Updated file: Reports/meditations_transcripts\raw\Compassion\S313.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\ID 05.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 08.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 13.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 13b.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 14.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 15.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 16.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 17.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 18.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 19.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 19b.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 22.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 23.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 24.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 24b.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 7a.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Id 7b.csv
# Updated file: Reports/meditations_transcripts\raw\OBE1\Participant 20 interview.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S201\S201-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S201\S201-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S201\S201-3.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S202\S202-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S203\S203-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S204\S204-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S204\S204-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S205\S205-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S205\S205-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S206\S206-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S206\S206-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S207\S207-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S207\S207-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S208\S208-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S208\S208-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S209\S209-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S209\S209-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S209\S209-3.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S209\S209-4.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S210\S210-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S210\S210-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S210\S210-3.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S211\S211_1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S211\S211_2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S211\S211_3 (partially in french).csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S212\S212_1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S212\S212_2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S213\S213_1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S213\S213_2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S214\S214_1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S214\S214_2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S217\S217.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S218\S218-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S218\S218-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S219\S219-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S219\S219-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S220\S220-1.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S220\S220-2.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S222\S222_c.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S222\S222_m.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S223\S223.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S225\S225.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S225\S225[1].csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S226\S226.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S226\S226[1].csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S226\S226[2].csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S227\S227 control interview.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S227\S227 intervention.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S228\S228 control.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S228\S228 intervention.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S229\S229 control.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S229\S229 intervention.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S230\S230 control.csv
# Updated file: Reports/meditations_transcripts\raw\OBE2\S230\S230 intervention.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S301final.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S302con.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S302man.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S303con.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S303man.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S304.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S305con.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S306.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S307.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\Compassion\S313.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\ID 05.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 08.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 13.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 13b.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 14.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 15.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 16.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 17.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 18.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 19.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 19b.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 22.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 23.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 24.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 24b.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 7a.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Id 7b.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE1\Participant 20 interview.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S201-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S201-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S201-3.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S202-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S203-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S204-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S204-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S205-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S205-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S206-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S206-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S207-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S207-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S208-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S208-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S209-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S209-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S209-3.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S209-4.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S210-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S210-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S210-3.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S211_1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S211_2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S211_3 (partially in french).csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S212_1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S212_2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S213_1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S213_2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S214_1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S214_2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S217.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S218-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S218-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S219-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S219-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S220-1.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S220-2.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S222_c.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S222_m.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S223.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S225.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S225[1].csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S226.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S226[1].csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S226[2].csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S227 control interview.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S227 intervention.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S228 control.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S228 intervention.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S229 control.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S229 intervention.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S230 control.csv
# Updated file: Reports/meditations_transcripts\transcripts_per_interview\csv\OBE2\S230 intervention.csv

# %%
import os
import pandas as pd

def replace_brackets_in_csv(directory, column_name):
    """
    Recursively looks into a directory for CSV files, replaces square brackets [ ] 
    with parentheses ( ) in a specific column, and prints the content every time a change is made.

    :param directory: The root directory to start searching for CSV files.
    :param column_name: The name of the column to modify.
    """
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.csv'):
                file_path = os.path.join(root, file)
                try:
                    # Read the CSV file
                    df = pd.read_csv(file_path)

                    # Check if the column exists in the CSV
                    if column_name in df.columns:
                        # Replace brackets [] with parentheses () in the specific column
                        original_values = df[column_name].tolist()  # Save original values for comparison
                        df[column_name] = df[column_name].astype(str).str.replace(r'\[', '(', regex=True).str.replace(r'\]', ')', regex=True)

                        # Print the content every time a change is made
                        for original, modified in zip(original_values, df[column_name].tolist()):
                            if original != modified:
                                print(f"File: {file_path}")
                                print(f"Original: {original}")
                                print(f"Modified: {modified}")
                                print("-" * 50)

                        # Save the modified CSV back to the file
                        df.to_csv(file_path, index=False)
                except Exception as e:
                    print(f"Error processing file {file_path}: {e}")

# Example usage
#replace_brackets_in_csv("evaluation/references", 'Content')
# Out:
# File: evaluation/references\ID 05.csv
# Original: Yes. [END INTERVIEW]
# Modified: Yes. (END INTERVIEW)
# --------------------------------------------------
# File: evaluation/references\Id 08.csv
# Original: [BEGIN INTERVIEW] how was uh the second part?
# Modified: (BEGIN INTERVIEW) how was uh the second part?
# --------------------------------------------------
# File: evaluation/references\Id 7a.csv
# Original: Time-Stamps are shfited & mostly in french...[START INTERVIEW] 00:04:02
# Modified: Time-Stamps are shfited & mostly in french...(START INTERVIEW) 00:04:02
# --------------------------------------------------
# File: evaluation/references\S201-2.csv
# Original: [SMALL TALK overlapping] And if you want coffee after, I also can.
# Modified: (SMALL TALK overlapping) And if you want coffee after, I also can.
# --------------------------------------------------
# File: evaluation/references\S201-2.csv
# Original: I mean, yes, there is always a bit of a risk because when we put this headset, it's not that easy to put. [END SMALL TALK]
# Modified: I mean, yes, there is always a bit of a risk because when we put this headset, it's not that easy to put. (END SMALL TALK)
# --------------------------------------------------
# File: evaluation/references\S202-1.csv
# Original: [END INTERVIEW]Do you have my email?
# Modified: (END INTERVIEW)Do you have my email?
# --------------------------------------------------
# File: evaluation/references\S203-1.csv
# Original: You din't felt attached from what you see? [START very complicated to understand exchange]
# Modified: You din't felt attached from what you see? (START very complicated to understand exchange)
# --------------------------------------------------
# File: evaluation/references\S203-1.csv
# Original: Okay, so I see, is complete normal [END bad audio exchange]
# Modified: Okay, so I see, is complete normal (END bad audio exchange)
# --------------------------------------------------
# File: evaluation/references\S208-1.csv
# Original: I hope more beautiful. [END INTERVIEW]
# Modified: I hope more beautiful. (END INTERVIEW)
# --------------------------------------------------
# File: evaluation/references\S208-2.csv
# Original: Oh, okay, that makes sense. [END INTERVIEW]
# Modified: Oh, okay, that makes sense. (END INTERVIEW)
# --------------------------------------------------
# File: evaluation/references\S209-1.csv
# Original: okay okay yeah okay. [END INTERVIEW]
# Modified: okay okay yeah okay. (END INTERVIEW)
# --------------------------------------------------
# File: evaluation/references\S209-4.csv
# Original: just a very small question just for you just how you feel questions. [END INTERVIEW]
# Modified: just a very small question just for you just how you feel questions. (END INTERVIEW)
# --------------------------------------------------
# File: evaluation/references\S209-4.csv
# Original: Okay, then there's on the other side. [END interesting info]
# Modified: Okay, then there's on the other side. (END interesting info)
# --------------------------------------------------
# File: evaluation/references\S210-3.csv
# Original: in terms of questions and then feedback also maybe that can give you uh more ideas of what you thought and then we can also discuss questions. [QUESTIONARY TIME]
# Modified: in terms of questions and then feedback also maybe that can give you uh more ideas of what you thought and then we can also discuss questions. (QUESTIONARY TIME)
# --------------------------------------------------
# File: evaluation/references\S211_1.csv
# Original: But there was still... maybe it's 50-50. [END INTERVIEW]
# Modified: But there was still... maybe it's 50-50. (END INTERVIEW)
# --------------------------------------------------
# File: evaluation/references\S211_3 (partially in french).csv
# Original: [blabla] I didn't remember a word.
# Modified: (blabla) I didn't remember a word.
# --------------------------------------------------
# File: evaluation/references\S211_3 (partially in french).csv
# Original: Thank you. [blabla]
# Modified: Thank you. (blabla)
# --------------------------------------------------
# File: evaluation/references\S212_1.csv
# Original: I have many questions too! [Questionaire TIME]
# Modified: I have many questions too! (Questionaire TIME)
# --------------------------------------------------
# File: evaluation/references\S217.csv
# Original: And I think this time our questionnaire should work. [QUESTIONAIRE FOR 4 min]
# Modified: And I think this time our questionnaire should work. (QUESTIONAIRE FOR 4 min)
# --------------------------------------------------
# File: evaluation/references\S223.csv
# Original: Yes the first session, I was like quite [?]
# Modified: Yes the first session, I was like quite (?)
# --------------------------------------------------
# File: evaluation/references\S223.csv
# Original: but like I prefer it close, that like the experience [...]
# Modified: but like I prefer it close, that like the experience (...)
# --------------------------------------------------
# File: evaluation/references\S225.csv
# Original: yes it was, uh [...]
# Modified: yes it was, uh (...)
# --------------------------------------------------
# File: evaluation/references\S227 control interview.csv
# Original: I think I'm really in the [...INAUDIBLE]
# Modified: I think I'm really in the (...INAUDIBLE)
# --------------------------------------------------
# File: evaluation/references\S227 intervention.csv
# Original: Yes when I move a hand but not when [...]
# Modified: Yes when I move a hand but not when (...)
# --------------------------------------------------
# File: evaluation/references\S227 intervention.csv
# Original: um I'm not sure whether the first time and the second time they are the same place. But I think the [...] was more [real?] and more relax.
# Modified: um I'm not sure whether the first time and the second time they are the same place. But I think the (...) was more (real?) and more relax.
# --------------------------------------------------
# File: evaluation/references\S229 control.csv
# Original: Yeah that is the thing... [NOISE MICRO]
# Modified: Yeah that is the thing... (NOISE MICRO)
# --------------------------------------------------
# File: evaluation/references\S229 intervention.csv
# Original: you want to go back to your body in that or just maybe little a dream [...] What type of changes did you mean?
# Modified: you want to go back to your body in that or just maybe little a dream (...) What type of changes did you mean?
# --------------------------------------------------
# File: evaluation/references\S229 intervention.csv
# Original: sometimes the inside is not precise in the past [..] what corresponds to the reality of things.
# Modified: sometimes the inside is not precise in the past (..) what corresponds to the reality of things.
# --------------------------------------------------
# File: evaluation/references\S229 intervention.csv
# Original: What do you think? [Joke]
# Modified: What do you think? (Joke)
# --------------------------------------------------
# File: evaluation/references\S230 control.csv
# Original:  Yeah, when I saw myself being hit or when I saw you swicthing sides, like I convice that I would [be me?] it in that part.
# Modified:  Yeah, when I saw myself being hit or when I saw you swicthing sides, like I convice that I would (be me?) it in that part.
# --------------------------------------------------
# File: evaluation/references\S230 intervention.csv
# Original: Yeah at the beginning yeah, like I just looked at the CCTV [ Closed-circuit television ==  video surveillance] of myself.
# Modified: Yeah at the beginning yeah, like I just looked at the CCTV ( Closed-circuit television ==  video surveillance) of myself.
# --------------------------------------------------

# %% [markdown]
# ## Excel to csv

# %%
import pandas as pd

df = pd.read_excel('./interviews_corrected/structured_data_manual.xlsx')
# Remove the last column
df = df.iloc[:, :-1]

df.to_csv('./structured_data_manual.csv', index=False)
df
# Out:
# c:\Users\david\anaconda3\envs\basic\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#     Experiment File Name   Id  Duration Order Condition Condition
# 0         OBE1     ID 05    5  00:10:15              IC         1
# 1         OBE1     Id 7a    7  00:09:38              IC         I
# 2         OBE1     Id 7b    7  00:04:01              IC         C
# 3         OBE1     Id 08    8  00:04:34              CI         1
# 4         OBE1     Id 13   13  00:07:19              IC         I
# ..         ...       ...  ...       ...             ...       ...
# 77  Compassion      S304  304  00:07:05              CI         1
# 78  Compassion   S305con  305  00:01:41              CI         C
# 79  Compassion      S306  306  00:08:50              IC         1
# 80  Compassion      S307  307  00:06:15              CI         1
# 81  Compassion      S313  313  00:09:36              IC         1
#
# [82 rows x 6 columns]

# %%
import requests

url = "https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip"
output = "BLEURT-20.zip"

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    with open(output, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
print("Download completed.")

# %%
from src.utils.preprocessing_helpers import preprocessing_csv

str_file="src/test_erro/ADE_pilot_012_interview_21.11.24_part1.str"

preprocessing_csv(str_file=str_file)
# Out:
# Saved preprocessed file to results\processed\..\src\test_erro\ADE_pilot_012_interview_21.11.24_part1.csv
