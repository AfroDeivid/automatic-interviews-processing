# %%
import whisperx
import gc

# %%
device= "cpu"
audio_file = "./data/OBE1/Id 16.m4a"
batch_size = 16 # reduce if low on GPU mem
#compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)
compute_type = "int8"

# %%
# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("large-v2",device, compute_type=compute_type)
# Out:
# No language specified, language will be first be detected for each audio file (increases inference time).
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.3.3. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\david\.cache\torch\whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.0. Bad things might happen unless you revert torch to 1.x.

# %%
# save model to local path (optional)
# model_dir = "/path/"
# model = whisperx.load_model("large-v2", device, compute_type=compute_type, download_root=model_dir)

# %%
audio = whisperx.load_audio(audio_file)
transcript = model.transcribe(audio, batch_size=batch_size)
print(transcript["segments"]) # before alignment
# Out:
# Detected language: en (0.74) in first 30s of audio...
# [{'text': ' uh, your body and the virtual visualization of your body. Do you have a feeling that you were separated with the body? Not at 100%, but somewhat, yes. Somewhat, you feel like, OK, your body, the body in front of you is yourself, and then you somehow feel separated. Yeah. How was the feeling? Did you feel, like, any, like, discomfort? Or you feel, like, more pleasant?', 'start': 0.111, 'end': 28.08}, {'text': " It's more, let's say, weirdness. Weirdness. It was not discophonic at all. And it was not pleasant that much. So it was like weird to see that. It's like kind of... Weird means a little bit confused or is it more like excited? More confused.", 'start': 28.08, 'end': 52.671}, {'text': ' Okay, and during the first two parts, could you follow this time better than the last time in the first section? Yes. So you could follow the body scanning part with the eyes closed, how did you feel? Could you do everything he asked you to do?', 'start': 52.858, 'end': 74.701}, {'text': " Uh, yeah. At the beginning, yes. But not after seeing the body, like, moving in front of me. But just before, yeah. But before, when he asked you to observe the thoughts, you able to do it? Or you have some mind wandering, like you have some thinking, OK, so you could concentrate on what he's saying. Yes. And after moving out of the body, what happened?", 'start': 75.35, 'end': 101.391}, {'text': " It was like a kind of disconnection. I don't know. It was like a weird sensation. I don't know how to describe it. It was just like... It's the first time you feel that. I don't know. It's kind of like separation sometimes. Yeah. Separation is maybe the word. Yeah, exactly.", 'start': 101.391, 'end': 123.831}, {'text': " In the first part I mean in the first part you didn't you feel anything weird like that no", 'start': 124.377, 'end': 136.647}, {'text': " But only the platform moving, so it's not really any feeling like in the second part, right? The second part where you separate your body. Yeah, exactly. So it's like the condition that we let you see your body have some effect. Yeah, definitely. So thank you. Thank you. Thank you very much.", 'start': 136.8, 'end': 157.312}]

# %%
# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model

# %%
# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=transcript["language"], device=device)
transcript_aligned = whisperx.align(transcript["segments"], model_a, metadata, audio, device, return_char_alignments=False)

print(transcript_aligned["segments"]) # after alignment
# Out:
# [{'start': 0.691, 'end': 5.073, 'text': ' uh, your body and the virtual visualization of your body.', 'words': [{'word': 'uh,', 'start': 0.691, 'end': 0.871, 'score': 0.684}, {'word': 'your', 'start': 1.031, 'end': 1.211, 'score': 0.896}, {'word': 'body', 'start': 1.291, 'end': 1.832, 'score': 0.945}, {'word': 'and', 'start': 2.132, 'end': 2.292, 'score': 0.855}, {'word': 'the', 'start': 2.392, 'end': 2.532, 'score': 0.846}, {'word': 'virtual', 'start': 2.672, 'end': 3.412, 'score': 0.704}, {'word': 'visualization', 'start': 3.572, 'end': 4.412, 'score': 0.659}, {'word': 'of', 'start': 4.452, 'end': 4.492, 'score': 0.598}, {'word': 'your', 'start': 4.592, 'end': 4.692, 'score': 0.201}, {'word': 'body.', 'start': 4.712, 'end': 5.073, 'score': 0.715}]}, {'start': 5.673, 'end': 8.374, 'text': 'Do you have a feeling that you were separated with the body?', 'words': [{'word': 'Do', 'start': 5.673, 'end': 5.713, 'score': 0.005}, {'word': 'you', 'start': 5.733, 'end': 5.813, 'score': 0.883}, {'word': 'have', 'start': 5.833, 'end': 5.993, 'score': 0.638}, {'word': 'a', 'start': 6.013, 'end': 6.033, 'score': 0.014}, {'word': 'feeling', 'start': 6.053, 'end': 6.293, 'score': 0.91}, {'word': 'that', 'start': 6.333, 'end': 6.513, 'score': 0.834}, {'word': 'you', 'start': 6.593, 'end': 6.833, 'score': 0.841}, {'word': 'were', 'start': 6.873, 'end': 7.033, 'score': 0.631}, {'word': 'separated', 'start': 7.073, 'end': 7.573, 'score': 0.934}, {'word': 'with', 'start': 7.613, 'end': 7.773, 'score': 0.896}, {'word': 'the', 'start': 7.833, 'end': 7.994, 'score': 0.259}, {'word': 'body?', 'start': 8.014, 'end': 8.374, 'score': 0.951}]}, {'start': 8.874, 'end': 12.755, 'text': 'Not at 100%, but somewhat, yes.', 'words': [{'word': 'Not', 'start': 8.874, 'end': 9.254, 'score': 0.908}, {'word': 'at', 'start': 9.834, 'end': 9.934, 'score': 0.54}, {'word': '100%,'}, {'word': 'but', 'start': 10.414, 'end': 11.135, 'score': 0.607}, {'word': 'somewhat,', 'start': 11.655, 'end': 12.395, 'score': 0.914}, {'word': 'yes.', 'start': 12.455, 'end': 12.755, 'score': 0.897}]}, {'start': 13.315, 'end': 19.917, 'text': 'Somewhat, you feel like, OK, your body, the body in front of you is yourself, and then you somehow feel separated.', 'words': [{'word': 'Somewhat,', 'start': 13.315, 'end': 14.075, 'score': 0.942}, {'word': 'you', 'start': 14.136, 'end': 14.276, 'score': 0.948}, {'word': 'feel', 'start': 14.316, 'end': 14.496, 'score': 0.959}, {'word': 'like,', 'start': 14.516, 'end': 14.676, 'score': 0.88}, {'word': 'OK,', 'start': 14.756, 'end': 14.976, 'score': 0.48}, {'word': 'your', 'start': 14.996, 'end': 15.096, 'score': 0.926}, {'word': 'body,', 'start': 15.116, 'end': 16.216, 'score': 0.89}, {'word': 'the', 'start': 16.236, 'end': 16.296, 'score': 0.928}, {'word': 'body', 'start': 16.336, 'end': 16.476, 'score': 0.496}, {'word': 'in', 'start': 16.496, 'end': 16.556, 'score': 0.966}, {'word': 'front', 'start': 16.596, 'end': 16.756, 'score': 0.901}, {'word': 'of', 'start': 16.776, 'end': 16.836, 'score': 0.752}, {'word': 'you', 'start': 16.876, 'end': 17.056, 'score': 0.888}, {'word': 'is', 'start': 17.156, 'end': 17.297, 'score': 0.882}, {'word': 'yourself,', 'start': 17.377, 'end': 17.857, 'score': 0.882}, {'word': 'and', 'start': 17.937, 'end': 18.017, 'score': 0.818}, {'word': 'then', 'start': 18.037, 'end': 18.197, 'score': 0.74}, {'word': 'you', 'start': 18.237, 'end': 18.537, 'score': 0.517}, {'word': 'somehow', 'start': 18.557, 'end': 18.917, 'score': 0.59}, {'word': 'feel', 'start': 18.957, 'end': 19.297, 'score': 0.472}, {'word': 'separated.', 'start': 19.437, 'end': 19.917, 'score': 0.898}]}, {'start': 19.937, 'end': 20.017, 'text': 'Yeah.', 'words': [{'word': 'Yeah.', 'start': 19.937, 'end': 20.017, 'score': 0.036}]}, {'start': 20.318, 'end': 21.078, 'text': 'How was the feeling?', 'words': [{'word': 'How', 'start': 20.318, 'end': 20.418, 'score': 0.951}, {'word': 'was', 'start': 20.438, 'end': 20.598, 'score': 0.516}, {'word': 'the', 'start': 20 ...

# %%
# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model_a

# %%
HF_TOKEN= "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"

# %%
# 3. Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token=HF_TOKEN, device=device)

# add min/max number of speakers if known
diarize_segments = diarize_model(audio,max_speakers=5) # min_speakers=2, num_speakers=3

# %%
result = whisperx.assign_word_speakers(diarize_segments, transcript_aligned)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs

result["segments"]
# Out:
#                               segment label     speaker       start  \
# 0   [ 00:00:00.008 -->  00:00:04.966]     A  SPEAKER_01    0.008489
# 1   [ 00:00:04.558 -->  00:00:05.067]     B  SPEAKER_00    4.558574
# 2   [ 00:00:05.118 -->  00:00:08.463]     C  SPEAKER_00    5.118846
# 3   [ 00:00:08.684 -->  00:00:13.030]     D  SPEAKER_01    8.684211
# 4   [ 00:00:13.234 -->  00:00:13.251]     E  SPEAKER_01   13.234295
# ..                                ...   ...         ...         ...
# 56  [ 00:02:24.609 -->  00:02:25.135]    BE  SPEAKER_01  144.609508
# 57  [ 00:02:25.220 -->  00:02:25.390]    BF  SPEAKER_01  145.220713
# 58  [ 00:02:25.967 -->  00:02:26.460]    BG  SPEAKER_01  145.967742
# 59  [ 00:02:27.088 -->  00:02:27.156]    BH  SPEAKER_01  147.088285
# 60  [ 00:02:32.283 -->  00:02:32.775]    BI  SPEAKER_01  152.283531
#
#            end  intersection       union
# 0     4.966044   -152.225956  157.263511
# 1     5.067912   -152.124088  152.713426
# 2     8.463497   -148.728503  152.153154
# 3    13.030560   -144.161440  148.587789
# 4    13.251273   -143.940727  144.037705
# ..         ...           ...         ...
# 56  145.135823    -12.056177   12.662492
# 57  145.390492    -11.801508   12.051287
# 58  146.460102    -10.731898   11.304258
# 59  147.156197    -10.035803   10.183715
# 60  152.775891     -4.416109    4.988469
#
# [61 rows x 7 columns]
# [{'start': 0.691, 'end': 5.073, 'text': ' uh, your body and the virtual visualization of your body.', 'words': [{'word': 'uh,', 'start': 0.691, 'end': 0.871, 'score': 0.684, 'speaker': 'SPEAKER_01'}, {'word': 'your', 'start': 1.031, 'end': 1.211, 'score': 0.896, 'speaker': 'SPEAKER_01'}, {'word': 'body', 'start': 1.291, 'end': 1.832, 'score': 0.945, 'speaker': 'SPEAKER_01'}, {'word': 'and', 'start': 2.132, 'end': 2.292, 'score': 0.855, 'speaker': 'SPEAKER_01'}, {'word': 'the', 'start': 2.392, 'end': 2.532, 'score': 0.846, 'speaker': 'SPEAKER_01'}, {'word': 'virtual', 'start': 2.672, 'end': 3.412, 'score': 0.704, 'speaker': 'SPEAKER_01'}, {'word': 'visualization', 'start': 3.572, 'end': 4.412, 'score': 0.659, 'speaker': 'SPEAKER_01'}, {'word': 'of', 'start': 4.452, 'end': 4.492, 'score': 0.598, 'speaker': 'SPEAKER_01'}, {'word': 'your', 'start': 4.592, 'end': 4.692, 'score': 0.201, 'speaker': 'SPEAKER_00'}, {'word': 'body.', 'start': 4.712, 'end': 5.073, 'score': 0.715, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_01'}, {'start': 5.673, 'end': 8.374, 'text': 'Do you have a feeling that you were separated with the body?', 'words': [{'word': 'Do', 'start': 5.673, 'end': 5.713, 'score': 0.005, 'speaker': 'SPEAKER_00'}, {'word': 'you', 'start': 5.733, 'end': 5.813, 'score': 0.883, 'speaker': 'SPEAKER_00'}, {'word': 'have', 'start': 5.833, 'end': 5.993, 'score': 0.638, 'speaker': 'SPEAKER_00'}, {'word': 'a', 'start': 6.013, 'end': 6.033, 'score': 0.014, 'speaker': 'SPEAKER_00'}, {'word': 'feeling', 'start': 6.053, 'end': 6.293, 'score': 0.91, 'speaker': 'SPEAKER_00'}, {'word': 'that', 'start': 6.333, 'end': 6.513, 'score': 0.834, 'speaker': 'SPEAKER_00'}, {'word': 'you', 'start': 6.593, 'end': 6.833, 'score': 0.841, 'speaker': 'SPEAKER_00'}, {'word': 'were', 'start': 6.873, 'end': 7.033, 'score': 0.631, 'speaker': 'SPEAKER_00'}, {'word': 'separated', 'start': 7.073, 'end': 7.573, 'score': 0.934, 'speaker': 'SPEAKER_00'}, {'word': 'with', 'start': 7.613, 'end': 7.773, 'score': 0.896, 'speaker': 'SPEAKER_00'}, {'word': 'the', 'start': 7.833, 'end': 7.994, 'score': 0.259, 'speaker': 'SPEAKER_00'}, {'word': 'body?', 'start': 8.014, 'end': 8.374, 'score': 0.951, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}, {'start': 8.874, 'end': 12.755, 'text': 'Not at 100%, but somewhat, yes.', 'words': [{'word': 'Not', 'start': 8.874, 'end': 9.254, 'score': 0.908, 'speaker': 'SPEAKER_01'}, {'word': 'at', 'start': 9.834, 'end': 9.934, 'score': 0.54, 'speaker': 'SPEAKER_01'}, {'word': '100%,'}, {'word': 'but', 'start': 10.414, 'end': 11.135, 'score': 0.607, 'speaker': 'SPEAKER_01'}, {'word': 'somewhat,', 'start': 11.655, 'end': 12.395, 'score': 0.914, 'speaker': 'SPEAKER_01'}, {'word': 'yes.', 'start': 12.455, 'end': 12.755, 'score': 0.897, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 13.315, 'end': 19.917, 'text': 'Somewhat, you feel like, OK, your body, the body in front of you is yourself, and then you somehow feel separated.', 'words': [{'word': 'Somewhat,', 'start': 13.315, 'end': 14.075, 'score': 0.942, 'speaker': 'SPEAKER_00'}, {'word': 'you', 'start': 14.136, 'end': 14.276, 'score': 0.948, 'speaker': 'SPEAKER_00'}, {'word': 'feel', 'start': 14.316, 'end': 14.496, 'score': 0.959, 'speaker': 'SPEAKER_00'}, {'word': 'like,', 'start': 14.516, 'end': 14.676, 'score': 0.88, 'speaker': 'SPEAKER_00'}, {'word': 'OK,', 'start': 14.756, 'end': 14.976, 'score': 0.48, 'speaker': 'SPEAKER_00'}, {'word': 'your', 'start': 14.996, 'end': 15.096, 'score': 0.926, 'speaker': 'SPEAKER_00'}, {'word': 'body,', 'start': 15.116, 'end': 16.216, 'score': 0.89, 'speaker': 'SPEAKER_00'}, {'word': 'the', 'start': 16.236, 'end': 16.296, 'score': 0.928, 'speaker': 'SPEAKER_00'}, {'word': 'body', 'start': 16.336, 'end': 16.476, 'score': 0.496, 'speaker': 'SPEAKER_00'}, {'word': 'in', 'start': 16.496, 'end': 16.556, 'score': 0.966, 'speaker': 'SPEAKER_00'}, {'word': 'front', 'start': 16.596, 'end': 16.756, 'score': 0.901, 'speaker': 'SPEAKER_00'}, {'w ...
# [{'start': 0.691,
#   'end': 5.073,
#   'text': ' uh, your body and the virtual visualization of your body.',
#   'words': [{'word': 'uh,',
#     'start': 0.691,
#     'end': 0.871,
#     'score': 0.684,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'your',
#     'start': 1.031,
#     'end': 1.211,
#     'score': 0.896,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'body',
#     'start': 1.291,
#     'end': 1.832,
#     'score': 0.945,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'and',
#     'start': 2.132,
#     'end': 2.292,
#     'score': 0.855,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'the',
#     'start': 2.392,
#     'end': 2.532,
#     'score': 0.846,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'virtual',
#     'start': 2.672,
#     'end': 3.412,
#     'score': 0.704,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'visualization',
#     'start': 3.572,
#     'end': 4.412,
#     'score': 0.659,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'of',
#     'start': 4.452,
#     'end': 4.492,
#     'score': 0.598,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'your',
#     'start': 4.592,
#     'end': 4.692,
#     'score': 0.201,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body.',
#     'start': 4.712,
#     'end': 5.073,
#     'score': 0.715,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 5.673,
#   'end': 8.374,
#   'text': 'Do you have a feeling that you were separated with the body?',
#   'words': [{'word': 'Do',
#     'start': 5.673,
#     'end': 5.713,
#     'score': 0.005,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 5.733,
#     'end': 5.813,
#     'score': 0.883,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'have',
#     'start': 5.833,
#     'end': 5.993,
#     'score': 0.638,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'a',
#     'start': 6.013,
#     'end': 6.033,
#     'score': 0.014,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feeling',
#     'start': 6.053,
#     'end': 6.293,
#     'score': 0.91,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'that',
#     'start': 6.333,
#     'end': 6.513,
#     'score': 0.834,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 6.593,
#     'end': 6.833,
#     'score': 0.841,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'were',
#     'start': 6.873,
#     'end': 7.033,
#     'score': 0.631,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'separated',
#     'start': 7.073,
#     'end': 7.573,
#     'score': 0.934,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'with',
#     'start': 7.613,
#     'end': 7.773,
#     'score': 0.896,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 7.833,
#     'end': 7.994,
#     'score': 0.259,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body?',
#     'start': 8.014,
#     'end': 8.374,
#     'score': 0.951,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 8.874,
#   'end': 12.755,
#   'text': 'Not at 100%, but somewhat, yes.',
#   'words': [{'word': 'Not',
#     'start': 8.874,
#     'end': 9.254,
#     'score': 0.908,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'at',
#     'start': 9.834,
#     'end': 9.934,
#     'score': 0.54,
#     'speaker': 'SPEAKER_01'},
#    {'word': '100%,'},
#    {'word': 'but',
#     'start': 10.414,
#     'end': 11.135,
#     'score': 0.607,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'somewhat,',
#     'start': 11.655,
#     'end': 12.395,
#     'score': 0.914,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'yes.',
#     'start': 12.455,
#     'end': 12.755,
#     'score': 0.897,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 13.315,
#   'end': 19.917,
#   'text': 'Somewhat, you feel like, OK, your body, the body in front of you is yourself, and then you somehow feel separated.',
#   'words': [{'word': 'Somewhat,',
#     'start': 13.315,
#     'end': 14.075,
#     'score': 0.942,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 14.136,
#     'end': 14.276,
#     'score': 0.948,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feel',
#     'start': 14.316,
#     'end': 14.496,
#     'score': 0.959,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like,',
#     'start': 14.516,
#     'end': 14.676,
#     'score': 0.88,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'OK,',
#     'start': 14.756,
#     'end': 14.976,
#     'score': 0.48,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'your',
#     'start': 14.996,
#     'end': 15.096,
#     'score': 0.926,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body,',
#     'start': 15.116,
#     'end': 16.216,
#     'score': 0.89,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 16.236,
#     'end': 16.296,
#     'score': 0.928,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body',
#     'start': 16.336,
#     'end': 16.476,
#     'score': 0.496,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'in',
#     'start': 16.496,
#     'end': 16.556,
#     'score': 0.966,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'front',
#     'start': 16.596,
#     'end': 16.756,
#     'score': 0.901,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'of',
#     'start': 16.776,
#     'end': 16.836,
#     'score': 0.752,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 16.876,
#     'end': 17.056,
#     'score': 0.888,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'is',
#     'start': 17.156,
#     'end': 17.297,
#     'score': 0.882,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'yourself,',
#     'start': 17.377,
#     'end': 17.857,
#     'score': 0.882,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'and',
#     'start': 17.937,
#     'end': 18.017,
#     'score': 0.818,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'then',
#     'start': 18.037,
#     'end': 18.197,
#     'score': 0.74,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 18.237,
#     'end': 18.537,
#     'score': 0.517,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'somehow',
#     'start': 18.557,
#     'end': 18.917,
#     'score': 0.59,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feel',
#     'start': 18.957,
#     'end': 19.297,
#     'score': 0.472,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'separated.',
#     'start': 19.437,
#     'end': 19.917,
#     'score': 0.898,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 19.937,
#   'end': 20.017,
#   'text': 'Yeah.',
#   'words': [{'word': 'Yeah.',
#     'start': 19.937,
#     'end': 20.017,
#     'score': 0.036,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 20.318,
#   'end': 21.078,
#   'text': 'How was the feeling?',
#   'words': [{'word': 'How',
#     'start': 20.318,
#     'end': 20.418,
#     'score': 0.951,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'was',
#     'start': 20.438,
#     'end': 20.598,
#     'score': 0.516,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 20.618,
#     'end': 20.738,
#     'score': 0.672,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feeling?',
#     'start': 20.758,
#     'end': 21.078,
#     'score': 0.969,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 21.098,
#   'end': 23.839,
#   'text': 'Did you feel, like, any, like, discomfort?',
#   'words': [{'word': 'Did',
#     'start': 21.098,
#     'end': 21.198,
#     'score': 0.417,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 21.218,
#     'end': 21.358,
#     'score': 0.984,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feel,',
#     'start': 21.398,
#     'end': 21.618,
#     'score': 0.914,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like,',
#     'start': 21.638,
#     'end': 21.778,
#     'score': 0.687,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'any,',
#     'start': 21.818,
#     'end': 22.098,
#     'score': 0.709,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like,',
#     'start': 22.618,
#     'end': 22.858,
#     'score': 0.929,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'discomfort?',
#     'start': 22.978,
#     'end': 23.839,
#     'score': 0.903,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 24.179,
#   'end': 26.399,
#   'text': 'Or you feel, like, more pleasant?',
#   'words': [{'word': 'Or',
#     'start': 24.179,
#     'end': 24.279,
#     'score': 0.93,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 24.319,
#     'end': 24.459,
#     'score': 0.957,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feel,',
#     'start': 24.499,
#     'end': 24.739,
#     'score': 0.921,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like,',
#     'start': 24.779,
#     'end': 25.039,
#     'score': 0.869,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'more',
#     'start': 25.119,
#     'end': 25.479,
#     'score': 0.652,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'pleasant?',
#     'start': 25.959,
#     'end': 26.399,
#     'score': 0.629,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 28.38,
#   'end': 31.341,
#   'text': " It's more, let's say, weirdness.",
#   'words': [{'word': "It's",
#     'start': 28.38,
#     'end': 28.5,
#     'score': 0.466,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'more,',
#     'start': 28.62,
#     'end': 29.0,
#     'score': 0.818,
#     'speaker': 'SPEAKER_01'},
#    {'word': "let's",
#     'start': 29.02,
#     'end': 29.321,
#     'score': 0.422,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'say,',
#     'start': 29.421,
#     'end': 30.001,
#     'score': 0.842,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'weirdness.',
#     'start': 30.661,
#     'end': 31.341,
#     'score': 0.904,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 32.042,
#   'end': 32.502,
#   'text': 'Weirdness.',
#   'words': [{'word': 'Weirdness.',
#     'start': 32.042,
#     'end': 32.502,
#     'score': 0.525,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 32.522,
#   'end': 34.123,
#   'text': 'It was not discophonic at all.',
#   'words': [{'word': 'It',
#     'start': 32.522,
#     'end': 32.562,
#     'score': 0.399,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'was',
#     'start': 32.582,
#     'end': 32.742,
#     'score': 0.378,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'not',
#     'start': 32.782,
#     'end': 33.042,
#     'score': 0.91,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'discophonic',
#     'start': 33.182,
#     'end': 33.723,
#     'score': 0.584,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'at',
#     'start': 33.803,
#     'end': 33.883,
#     'score': 0.558,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'all.',
#     'start': 33.963,
#     'end': 34.123,
#     'score': 0.781,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 35.063,
#   'end': 37.584,
#   'text': 'And it was not pleasant that much.',
#   'words': [{'word': 'And',
#     'start': 35.063,
#     'end': 35.183,
#     'score': 0.784,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'it',
#     'start': 35.283,
#     'end': 35.383,
#     'score': 0.61,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'was',
#     'start': 35.443,
#     'end': 35.583,
#     'score': 0.911,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'not',
#     'start': 35.603,
#     'end': 35.763,
#     'score': 0.884,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pleasant',
#     'start': 35.803,
#     'end': 36.184,
#     'score': 0.88,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'that',
#     'start': 37.004,
#     'end': 37.204,
#     'score': 0.982,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'much.',
#     'start': 37.304,
#     'end': 37.584,
#     'score': 0.906,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 38.825,
#   'end': 41.846,
#   'text': 'So it was like weird to see that.',
#   'words': [{'word': 'So',
#     'start': 38.825,
#     'end': 39.005,
#     'score': 0.558,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'it',
#     'start': 39.065,
#     'end': 39.145,
#     'score': 0.808,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'was',
#     'start': 39.165,
#     'end': 39.345,
#     'score': 0.872,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'like',
#     'start': 39.405,
#     'end': 39.665,
#     'score': 0.832,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'weird',
#     'start': 40.285,
#     'end': 40.566,
#     'score': 0.596,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'to',
#     'start': 40.626,
#     'end': 40.986,
#     'score': 0.881,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'see',
#     'start': 41.306,
#     'end': 41.586,
#     'score': 0.985,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'that.',
#     'start': 41.626,
#     'end': 41.846,
#     'score': 0.884,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 42.266,
#   'end': 49.53,
#   'text': "It's like kind of... Weird means a little bit confused or is it more like excited?",
#   'words': [{'word': "It's",
#     'start': 42.266,
#     'end': 42.386,
#     'score': 0.752,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 42.406,
#     'end': 42.546,
#     'score': 0.852,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'kind',
#     'start': 42.586,
#     'end': 43.327,
#     'score': 0.568,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'of...',
#     'start': 44.507,
#     'end': 44.607,
#     'score': 0.344,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'Weird',
#     'start': 44.767,
#     'end': 45.028,
#     'score': 0.534,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'means',
#     'start': 45.068,
#     'end': 45.348,
#     'score': 0.66,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'a',
#     'start': 45.368,
#     'end': 45.388,
#     'score': 0.009,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'little',
#     'start': 45.888,
#     'end': 46.028,
#     'score': 0.402,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'bit',
#     'start': 46.048,
#     'end': 46.168,
#     'score': 0.317,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'confused',
#     'start': 46.188,
#     'end': 46.808,
#     'score': 0.873,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'or',
#     'start': 47.149,
#     'end': 47.269,
#     'score': 0.436,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'is',
#     'start': 47.429,
#     'end': 47.509,
#     'score': 0.834,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'it',
#     'start': 47.549,
#     'end': 47.609,
#     'score': 0.399,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'more',
#     'start': 47.729,
#     'end': 47.969,
#     'score': 0.558,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 48.029,
#     'end': 48.269,
#     'score': 0.901,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'excited?',
#     'start': 48.449,
#     'end': 49.53,
#     'score': 0.902,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 51.811,
#   'end': 52.491,
#   'text': 'More confused.',
#   'words': [{'word': 'More',
#     'start': 51.811,
#     'end': 51.991,
#     'score': 0.759,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'confused.',
#     'start': 52.011,
#     'end': 52.491,
#     'score': 0.882,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 54.3,
#   'end': 62.408,
#   'text': ' Okay, and during the first two parts, could you follow this time better than the last time in the first section?',
#   'words': [{'word': 'Okay,',
#     'start': 54.3,
#     'end': 54.56,
#     'score': 0.686,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'and',
#     'start': 54.74,
#     'end': 54.84,
#     'score': 0.864,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'during',
#     'start': 54.86,
#     'end': 55.1,
#     'score': 0.933,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 55.14,
#     'end': 55.22,
#     'score': 0.907,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'first',
#     'start': 55.241,
#     'end': 56.502,
#     'score': 0.861,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'two',
#     'start': 56.522,
#     'end': 56.662,
#     'score': 0.812,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'parts,',
#     'start': 56.722,
#     'end': 57.102,
#     'score': 0.766,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'could',
#     'start': 59.024,
#     'end': 59.185,
#     'score': 0.885,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 59.205,
#     'end': 59.305,
#     'score': 0.875,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'follow',
#     'start': 59.345,
#     'end': 59.625,
#     'score': 0.806,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'this',
#     'start': 59.665,
#     'end': 59.805,
#     'score': 0.778,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'time',
#     'start': 59.845,
#     'end': 60.026,
#     'score': 0.819,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'better',
#     'start': 60.066,
#     'end': 60.306,
#     'score': 0.928,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'than',
#     'start': 60.326,
#     'end': 60.446,
#     'score': 0.871,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 60.466,
#     'end': 60.526,
#     'score': 0.968,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'last',
#     'start': 60.566,
#     'end': 60.746,
#     'score': 0.861,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'time',
#     'start': 60.806,
#     'end': 61.067,
#     'score': 0.912,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'in',
#     'start': 61.267,
#     'end': 61.327,
#     'score': 0.942,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 61.347,
#     'end': 61.427,
#     'score': 0.808,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'first',
#     'start': 61.447,
#     'end': 61.767,
#     'score': 0.518,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'section?',
#     'start': 62.088,
#     'end': 62.408,
#     'score': 0.887,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 64.41,
#   'end': 64.65,
#   'text': 'Yes.',
#   'words': [{'word': 'Yes.',
#     'start': 64.41,
#     'end': 64.65,
#     'score': 0.924,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 66.633,
#   'end': 70.557,
#   'text': 'So you could follow the body scanning part with the eyes closed, how did you feel?',
#   'words': [{'word': 'So',
#     'start': 66.633,
#     'end': 66.733,
#     'score': 0.995,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 66.773,
#     'end': 66.833,
#     'score': 0.974,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'could',
#     'start': 66.873,
#     'end': 66.993,
#     'score': 0.992,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'follow',
#     'start': 67.033,
#     'end': 67.293,
#     'score': 0.951,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 67.854,
#     'end': 67.954,
#     'score': 0.877,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body',
#     'start': 67.974,
#     'end': 68.254,
#     'score': 0.882,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'scanning',
#     'start': 68.274,
#     'end': 68.615,
#     'score': 0.842,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'part',
#     'start': 68.655,
#     'end': 68.835,
#     'score': 0.957,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'with',
#     'start': 68.855,
#     'end': 68.975,
#     'score': 0.761,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 68.995,
#     'end': 69.075,
#     'score': 0.797,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'eyes',
#     'start': 69.155,
#     'end': 69.255,
#     'score': 0.742,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'closed,',
#     'start': 69.295,
#     'end': 69.576,
#     'score': 0.608,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'how',
#     'start': 69.616,
#     'end': 69.856,
#     'score': 0.923,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'did',
#     'start': 69.876,
#     'end': 70.096,
#     'score': 0.426,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 70.116,
#     'end': 70.236,
#     'score': 0.89,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feel?',
#     'start': 70.276,
#     'end': 70.557,
#     'score': 0.691,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 70.597,
#   'end': 74.401,
#   'text': 'Could you do everything he asked you to do?',
#   'words': [{'word': 'Could',
#     'start': 70.597,
#     'end': 70.717,
#     'score': 0.991,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 70.757,
#     'end': 71.758,
#     'score': 0.636,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'do',
#     'start': 71.778,
#     'end': 71.858,
#     'score': 0.822,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'everything',
#     'start': 71.918,
#     'end': 72.238,
#     'score': 0.962,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'he',
#     'start': 72.298,
#     'end': 72.499,
#     'score': 0.912,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'asked',
#     'start': 73.9,
#     'end': 74.06,
#     'score': 0.69,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 74.08,
#     'end': 74.16,
#     'score': 0.33,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'to',
#     'start': 74.2,
#     'end': 74.261,
#     'score': 0.946,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'do?',
#     'start': 74.301,
#     'end': 74.401,
#     'score': 0.998,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 75.71,
#   'end': 76.071,
#   'text': ' Uh, yeah.',
#   'words': [{'word': 'Uh,',
#     'start': 75.71,
#     'end': 75.83,
#     'score': 0.565,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'yeah.',
#     'start': 75.89,
#     'end': 76.071,
#     'score': 0.591,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 77.011,
#   'end': 78.152,
#   'text': 'At the beginning, yes.',
#   'words': [{'word': 'At',
#     'start': 77.011,
#     'end': 77.071,
#     'score': 0.95,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'the',
#     'start': 77.111,
#     'end': 77.191,
#     'score': 0.936,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'beginning,',
#     'start': 77.232,
#     'end': 77.672,
#     'score': 0.938,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'yes.',
#     'start': 77.912,
#     'end': 78.152,
#     'score': 0.844,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 79.293,
#   'end': 84.017,
#   'text': 'But not after seeing the body, like, moving in front of me.',
#   'words': [{'word': 'But',
#     'start': 79.293,
#     'end': 79.513,
#     'score': 0.811,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'not',
#     'start': 79.593,
#     'end': 79.874,
#     'score': 0.87,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'after',
#     'start': 80.094,
#     'end': 80.454,
#     'score': 0.845,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'seeing',
#     'start': 80.574,
#     'end': 81.075,
#     'score': 0.865,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'the',
#     'start': 81.135,
#     'end': 81.235,
#     'score': 0.834,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'body,',
#     'start': 81.315,
#     'end': 81.735,
#     'score': 0.82,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'like,',
#     'start': 81.775,
#     'end': 82.015,
#     'score': 0.63,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moving',
#     'start': 82.616,
#     'end': 83.256,
#     'score': 0.729,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'in',
#     'start': 83.316,
#     'end': 83.437,
#     'score': 0.615,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'front',
#     'start': 83.497,
#     'end': 83.717,
#     'score': 0.474,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'of',
#     'start': 83.737,
#     'end': 83.797,
#     'score': 0.244,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'me.',
#     'start': 83.837,
#     'end': 84.017,
#     'score': 0.661,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 84.698,
#   'end': 86.479,
#   'text': 'But just before, yeah.',
#   'words': [{'word': 'But',
#     'start': 84.698,
#     'end': 85.018,
#     'score': 0.576,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'just',
#     'start': 85.058,
#     'end': 85.278,
#     'score': 0.868,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'before,',
#     'start': 85.338,
#     'end': 85.678,
#     'score': 0.926,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'yeah.',
#     'start': 85.718,
#     'end': 86.479,
#     'score': 0.698,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 86.499,
#   'end': 91.083,
#   'text': 'But before, when he asked you to observe the thoughts, you able to do it?',
#   'words': [{'word': 'But',
#     'start': 86.499,
#     'end': 86.819,
#     'score': 0.34,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'before,',
#     'start': 86.839,
#     'end': 87.039,
#     'score': 0.903,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'when',
#     'start': 87.079,
#     'end': 87.18,
#     'score': 0.984,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'he',
#     'start': 87.22,
#     'end': 87.28,
#     'score': 0.979,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'asked',
#     'start': 87.36,
#     'end': 87.5,
#     'score': 0.835,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 87.52,
#     'end': 87.62,
#     'score': 0.934,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'to',
#     'start': 87.66,
#     'end': 87.82,
#     'score': 0.84,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'observe',
#     'start': 88.621,
#     'end': 88.961,
#     'score': 0.835,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 88.981,
#     'end': 89.081,
#     'score': 0.71,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'thoughts,',
#     'start': 89.101,
#     'end': 89.682,
#     'score': 0.473,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 90.102,
#     'end': 90.282,
#     'score': 0.842,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'able',
#     'start': 90.442,
#     'end': 90.622,
#     'score': 0.802,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'to',
#     'start': 90.662,
#     'end': 90.742,
#     'score': 0.794,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'do',
#     'start': 90.782,
#     'end': 90.923,
#     'score': 0.874,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'it?',
#     'start': 91.003,
#     'end': 91.083,
#     'score': 0.756,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 91.303,
#   'end': 97.428,
#   'text': "Or you have some mind wandering, like you have some thinking, OK, so you could concentrate on what he's saying.",
#   'words': [{'word': 'Or',
#     'start': 91.303,
#     'end': 91.463,
#     'score': 0.602,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 91.483,
#     'end': 91.643,
#     'score': 0.777,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'have',
#     'start': 91.683,
#     'end': 91.903,
#     'score': 0.76,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'some',
#     'start': 91.943,
#     'end': 92.104,
#     'score': 0.969,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'mind',
#     'start': 92.344,
#     'end': 92.524,
#     'score': 0.377,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'wandering,',
#     'start': 92.564,
#     'end': 92.964,
#     'score': 0.757,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 93.004,
#     'end': 93.124,
#     'score': 0.367,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 93.144,
#     'end': 93.304,
#     'score': 0.981,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'have',
#     'start': 93.365,
#     'end': 93.585,
#     'score': 0.926,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'some',
#     'start': 93.645,
#     'end': 93.965,
#     'score': 0.714,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'thinking,',
#     'start': 94.125,
#     'end': 94.445,
#     'score': 0.85,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'OK,',
#     'start': 94.545,
#     'end': 94.826,
#     'score': 0.69,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'so',
#     'start': 94.886,
#     'end': 95.066,
#     'score': 0.412,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 95.086,
#     'end': 95.246,
#     'score': 0.765,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'could',
#     'start': 95.346,
#     'end': 95.546,
#     'score': 0.856,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'concentrate',
#     'start': 96.107,
#     'end': 96.787,
#     'score': 0.572,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'on',
#     'start': 96.807,
#     'end': 96.887,
#     'score': 0.512,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'what',
#     'start': 96.907,
#     'end': 97.027,
#     'score': 0.55,
#     'speaker': 'SPEAKER_00'},
#    {'word': "he's",
#     'start': 97.047,
#     'end': 97.168,
#     'score': 0.361,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'saying.',
#     'start': 97.188,
#     'end': 97.428,
#     'score': 0.807,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 98.128,
#   'end': 99.369,
#   'text': 'Yes.',
#   'words': [{'word': 'Yes.',
#     'start': 98.128,
#     'end': 99.369,
#     'score': 0.94,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 99.449,
#   'end': 101.071,
#   'text': 'And after moving out of the body, what happened?',
#   'words': [{'word': 'And',
#     'start': 99.449,
#     'end': 99.529,
#     'score': 0.942,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'after',
#     'start': 99.63,
#     'end': 99.83,
#     'score': 0.944,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'moving',
#     'start': 99.87,
#     'end': 100.15,
#     'score': 0.89,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'out',
#     'start': 100.25,
#     'end': 100.33,
#     'score': 0.592,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'of',
#     'start': 100.35,
#     'end': 100.39,
#     'score': 0.036,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 100.41,
#     'end': 100.47,
#     'score': 0.016,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body,',
#     'start': 100.49,
#     'end': 100.65,
#     'score': 0.539,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'what',
#     'start': 100.67,
#     'end': 100.791,
#     'score': 0.873,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'happened?',
#     'start': 100.831,
#     'end': 101.071,
#     'score': 0.98,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 101.911,
#   'end': 103.673,
#   'text': ' It was like a kind of disconnection.',
#   'words': [{'word': 'It',
#     'start': 101.911,
#     'end': 102.052,
#     'score': 0.476,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'was',
#     'start': 102.072,
#     'end': 102.252,
#     'score': 0.663,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'like',
#     'start': 102.292,
#     'end': 102.452,
#     'score': 0.869,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 102.492,
#     'end': 102.532,
#     'score': 0.478,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'kind',
#     'start': 102.592,
#     'end': 102.792,
#     'score': 0.909,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'of',
#     'start': 102.832,
#     'end': 102.892,
#     'score': 0.749,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'disconnection.',
#     'start': 102.972,
#     'end': 103.673,
#     'score': 0.869,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 103.693,
#   'end': 105.775,
#   'text': "I don't know.",
#   'words': [{'word': 'I',
#     'start': 103.693,
#     'end': 103.713,
#     'score': 0.0,
#     'speaker': 'SPEAKER_01'},
#    {'word': "don't",
#     'start': 103.733,
#     'end': 103.833,
#     'score': 0.077,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'know.',
#     'start': 105.615,
#     'end': 105.775,
#     'score': 0.698,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 105.835,
#   'end': 109.018,
#   'text': 'It was like a weird sensation.',
#   'words': [{'word': 'It',
#     'start': 105.835,
#     'end': 105.935,
#     'score': 0.664,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'was',
#     'start': 105.955,
#     'end': 106.235,
#     'score': 0.805,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'like',
#     'start': 106.295,
#     'end': 106.476,
#     'score': 0.87,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 106.556,
#     'end': 106.576,
#     'score': 0.954,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'weird',
#     'start': 106.696,
#     'end': 107.276,
#     'score': 0.831,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sensation.',
#     'start': 107.637,
#     'end': 109.018,
#     'score': 0.661,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 110.059,
#   'end': 111.44,
#   'text': "I don't know how to describe it.",
#   'words': [{'word': 'I',
#     'start': 110.059,
#     'end': 110.139,
#     'score': 0.769,
#     'speaker': 'SPEAKER_00'},
#    {'word': "don't",
#     'start': 110.159,
#     'end': 110.279,
#     'score': 0.152,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'know',
#     'start': 110.299,
#     'end': 110.419,
#     'score': 0.595,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'how',
#     'start': 110.439,
#     'end': 110.539,
#     'score': 0.365,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'to',
#     'start': 110.559,
#     'end': 110.659,
#     'score': 0.316,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'describe',
#     'start': 110.759,
#     'end': 111.24,
#     'score': 0.783,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'it.',
#     'start': 111.3,
#     'end': 111.44,
#     'score': 0.638,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 111.58,
#   'end': 115.223,
#   'text': "It was just like... It's the first time you feel that.",
#   'words': [{'word': 'It',
#     'start': 111.58,
#     'end': 111.64,
#     'score': 0.633,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'was',
#     'start': 111.68,
#     'end': 111.84,
#     'score': 0.94,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'just',
#     'start': 111.9,
#     'end': 112.081,
#     'score': 0.965,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'like...',
#     'start': 112.141,
#     'end': 112.401,
#     'score': 0.778,
#     'speaker': 'SPEAKER_01'},
#    {'word': "It's",
#     'start': 113.702,
#     'end': 113.822,
#     'score': 0.854,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'the',
#     'start': 113.862,
#     'end': 113.962,
#     'score': 0.93,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'first',
#     'start': 114.002,
#     'end': 114.202,
#     'score': 0.768,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'time',
#     'start': 114.242,
#     'end': 114.403,
#     'score': 0.843,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'you',
#     'start': 114.443,
#     'end': 114.643,
#     'score': 0.921,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'feel',
#     'start': 114.683,
#     'end': 114.943,
#     'score': 0.928,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'that.',
#     'start': 114.983,
#     'end': 115.223,
#     'score': 0.914,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 115.484,
#   'end': 116.164,
#   'text': "I don't know.",
#   'words': [{'word': 'I',
#     'start': 115.484,
#     'end': 115.564,
#     'score': 0.493,
#     'speaker': 'SPEAKER_01'},
#    {'word': "don't",
#     'start': 115.584,
#     'end': 115.724,
#     'score': 0.552,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'know.',
#     'start': 115.744,
#     'end': 116.164,
#     'score': 0.55,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 117.285,
#   'end': 119.387,
#   'text': "It's kind of like separation sometimes.",
#   'words': [{'word': "It's",
#     'start': 117.285,
#     'end': 117.365,
#     'score': 0.159,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'kind',
#     'start': 117.385,
#     'end': 117.505,
#     'score': 0.422,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'of',
#     'start': 117.545,
#     'end': 117.645,
#     'score': 0.674,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 117.706,
#     'end': 117.906,
#     'score': 0.794,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'separation',
#     'start': 117.926,
#     'end': 118.566,
#     'score': 0.828,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'sometimes.',
#     'start': 118.666,
#     'end': 119.387,
#     'score': 0.847,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 120.008,
#   'end': 120.208,
#   'text': 'Yeah.',
#   'words': [{'word': 'Yeah.',
#     'start': 120.008,
#     'end': 120.208,
#     'score': 0.58,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 120.228,
#   'end': 121.609,
#   'text': 'Separation is maybe the word.',
#   'words': [{'word': 'Separation',
#     'start': 120.228,
#     'end': 120.728,
#     'score': 0.871,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'is',
#     'start': 120.808,
#     'end': 121.029,
#     'score': 0.665,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'maybe',
#     'start': 121.049,
#     'end': 121.209,
#     'score': 0.306,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 121.229,
#     'end': 121.369,
#     'score': 0.353,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'word.',
#     'start': 121.389,
#     'end': 121.609,
#     'score': 0.694,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 122.37,
#   'end': 123.05,
#   'text': 'Yeah, exactly.',
#   'words': [{'word': 'Yeah,',
#     'start': 122.37,
#     'end': 122.57,
#     'score': 0.435,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'exactly.',
#     'start': 122.65,
#     'end': 123.05,
#     'score': 0.93,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 125.278,
#   'end': 136.447,
#   'text': " In the first part I mean in the first part you didn't you feel anything weird like that no",
#   'words': [{'word': 'In',
#     'start': 125.278,
#     'end': 126.158,
#     'score': 0.803,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 130.782,
#     'end': 130.862,
#     'score': 0.958,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'first',
#     'start': 130.882,
#     'end': 131.102,
#     'score': 0.587,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'part',
#     'start': 131.143,
#     'end': 131.403,
#     'score': 0.941,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'I',
#     'start': 131.703,
#     'end': 131.743,
#     'score': 0.487,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'mean',
#     'start': 131.763,
#     'end': 132.023,
#     'score': 0.646,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'in',
#     'start': 132.063,
#     'end': 132.123,
#     'score': 0.809,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 132.143,
#     'end': 132.223,
#     'score': 0.775,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'first',
#     'start': 132.243,
#     'end': 132.484,
#     'score': 0.639,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'part',
#     'start': 132.524,
#     'end': 132.804,
#     'score': 0.948,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 132.884,
#     'end': 133.004,
#     'score': 0.842,
#     'speaker': 'SPEAKER_00'},
#    {'word': "didn't",
#     'start': 133.024,
#     'end': 133.224,
#     'score': 0.896,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 133.665,
#     'end': 133.765,
#     'score': 0.916,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feel',
#     'start': 133.785,
#     'end': 133.925,
#     'score': 0.957,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'anything',
#     'start': 134.005,
#     'end': 134.325,
#     'score': 0.887,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'weird',
#     'start': 134.365,
#     'end': 134.685,
#     'score': 0.448,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 134.725,
#     'end': 134.886,
#     'score': 0.874,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'that',
#     'start': 134.906,
#     'end': 135.106,
#     'score': 0.834,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'no',
#     'start': 136.307,
#     'end': 136.447,
#     'score': 0.558,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 137.741,
#   'end': 142.483,
#   'text': " But only the platform moving, so it's not really any feeling like in the second part, right?",
#   'words': [{'word': 'But',
#     'start': 137.741,
#     'end': 138.301,
#     'score': 0.538,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'only',
#     'start': 138.341,
#     'end': 138.481,
#     'score': 0.673,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 138.501,
#     'end': 138.581,
#     'score': 0.657,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'platform',
#     'start': 138.601,
#     'end': 139.001,
#     'score': 0.652,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'moving,',
#     'start': 139.041,
#     'end': 139.341,
#     'score': 0.91,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'so',
#     'start': 139.402,
#     'end': 139.622,
#     'score': 0.829,
#     'speaker': 'SPEAKER_00'},
#    {'word': "it's",
#     'start': 139.822,
#     'end': 140.082,
#     'score': 0.438,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'not',
#     'start': 140.122,
#     'end': 140.242,
#     'score': 0.959,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'really',
#     'start': 140.282,
#     'end': 140.522,
#     'score': 0.815,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'any',
#     'start': 140.602,
#     'end': 140.802,
#     'score': 0.82,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'feeling',
#     'start': 140.922,
#     'end': 141.203,
#     'score': 0.87,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 141.243,
#     'end': 141.503,
#     'score': 0.657,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'in',
#     'start': 141.723,
#     'end': 141.763,
#     'score': 0.972,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 141.783,
#     'end': 141.843,
#     'score': 0.651,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'second',
#     'start': 141.883,
#     'end': 142.083,
#     'score': 0.902,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'part,',
#     'start': 142.103,
#     'end': 142.283,
#     'score': 0.671,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'right?',
#     'start': 142.323,
#     'end': 142.483,
#     'score': 0.831,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 142.964,
#   'end': 145.245,
#   'text': 'The second part where you separate your body.',
#   'words': [{'word': 'The',
#     'start': 142.964,
#     'end': 143.084,
#     'score': 0.796,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'second',
#     'start': 143.104,
#     'end': 143.324,
#     'score': 0.899,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'part',
#     'start': 143.344,
#     'end': 143.504,
#     'score': 0.882,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'where',
#     'start': 143.544,
#     'end': 143.844,
#     'score': 0.699,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 143.884,
#     'end': 144.124,
#     'score': 0.887,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'separate',
#     'start': 144.284,
#     'end': 144.685,
#     'score': 0.788,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'your',
#     'start': 144.725,
#     'end': 144.965,
#     'score': 0.48,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body.',
#     'start': 144.985,
#     'end': 145.245,
#     'score': 0.925,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 145.305,
#   'end': 146.646,
#   'text': 'Yeah, exactly.',
#   'words': [{'word': 'Yeah,',
#     'start': 145.305,
#     'end': 145.505,
#     'score': 0.475,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'exactly.',
#     'start': 146.286,
#     'end': 146.646,
#     'score': 0.934,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 147.546,
#   'end': 152.269,
#   'text': "So it's like the condition that we let you see your body have some effect.",
#   'words': [{'word': 'So',
#     'start': 147.546,
#     'end': 147.706,
#     'score': 0.901,
#     'speaker': 'SPEAKER_00'},
#    {'word': "it's",
#     'start': 147.746,
#     'end': 147.866,
#     'score': 0.502,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'like',
#     'start': 147.927,
#     'end': 148.127,
#     'score': 0.964,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'the',
#     'start': 148.507,
#     'end': 148.587,
#     'score': 0.765,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'condition',
#     'start': 148.607,
#     'end': 148.927,
#     'score': 0.93,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'that',
#     'start': 148.967,
#     'end': 149.087,
#     'score': 0.728,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'we',
#     'start': 149.147,
#     'end': 149.407,
#     'score': 0.575,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'let',
#     'start': 150.348,
#     'end': 150.508,
#     'score': 0.895,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 150.548,
#     'end': 150.688,
#     'score': 0.881,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'see',
#     'start': 150.748,
#     'end': 150.908,
#     'score': 0.869,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'your',
#     'start': 150.928,
#     'end': 151.068,
#     'score': 0.733,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'body',
#     'start': 151.088,
#     'end': 151.389,
#     'score': 0.867,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'have',
#     'start': 151.489,
#     'end': 151.649,
#     'score': 0.871,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'some',
#     'start': 151.709,
#     'end': 151.869,
#     'score': 0.958,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'effect.',
#     'start': 151.989,
#     'end': 152.269,
#     'score': 0.936,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 152.349,
#   'end': 153.59,
#   'text': 'Yeah, definitely.',
#   'words': [{'word': 'Yeah,',
#     'start': 152.349,
#     'end': 152.529,
#     'score': 0.431,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'definitely.',
#     'start': 152.569,
#     'end': 153.59,
#     'score': 0.642,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 153.61,
#   'end': 155.911,
#   'text': 'So thank you.',
#   'words': [{'word': 'So',
#     'start': 153.61,
#     'end': 153.81,
#     'score': 0.542,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'thank',
#     'start': 153.85,
#     'end': 154.01,
#     'score': 0.368,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you.',
#     'start': 155.451,
#     'end': 155.911,
#     'score': 0.784,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 156.051,
#   'end': 156.512,
#   'text': 'Thank you.',
#   'words': [{'word': 'Thank',
#     'start': 156.051,
#     'end': 156.231,
#     'score': 0.8,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you.',
#     'start': 156.271,
#     'end': 156.512,
#     'score': 0.808,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 156.532,
#   'end': 157.272,
#   'text': 'Thank you very much.',
#   'words': [{'word': 'Thank',
#     'start': 156.532,
#     'end': 156.672,
#     'score': 0.757,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'you',
#     'start': 156.692,
#     'end': 156.912,
#     'score': 0.549,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'very',
#     'start': 156.952,
#     'end': 157.172,
#     'score': 0.134,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'much.',
#     'start': 157.192,
#     'end': 157.272,
#     'score': 0.004,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'}]

# %%
with open("segments_output.txt", "w") as file:
    # Iterate through each segment in result["segments"]
    for segment in result["segments"]:
        # Extract text and speaker information
        text = segment["text"]
        speaker = segment["speaker"]
        
        # Write the text and speaker information to the file
        file.write(f"Speaker: {speaker}\nText: {text}\n\n")

# %%
with open("merged_segments_output.txt", "w") as file:
    # Initialize variables to keep track of the current speaker and their dialogue
    current_speaker = None
    current_dialogue = ""
    
    # Iterate through each segment in result["segments"]
    for segment in result["segments"]:
        speaker = segment["speaker"]
        text = segment["text"]
        
        # If the current segment's speaker is the same as the previous one, append the text
        if speaker == current_speaker:
            current_dialogue += " " + text
        else:
            # If the current segment's speaker is different, write the previous speaker's dialogue to the file
            if current_speaker is not None:
                file.write(f"{current_speaker}: {current_dialogue}\n\n")
            
            # Update the current speaker and dialogue
            current_speaker = speaker
            current_dialogue = text
    
    # Write the last speaker's dialogue to the file
    if current_speaker is not None:
        file.write(f"{current_speaker}: {current_dialogue}\n\n")
