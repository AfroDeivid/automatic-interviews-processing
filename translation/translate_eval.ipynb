# %%
# %load_ext autoreload
# %autoreload 2

# %%
from eval_translation_helpers import evaluate_metric_by_filename, evaluate_metrics_aggregated

# %%
from bleurt.score import BleurtScorer
# Load the BLEURT scorer with a pre-trained checkpoint
bleurt_checkpoint = "BLEURT-20"
scorer = BleurtScorer(bleurt_checkpoint)
# Out:
# WARNING:tensorflow:From c:\Users\david\anaconda3\envs\eval_transl\lib\site-packages\bleurt\score.py:160: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Reading checkpoint BLEURT-20.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint BLEURT-20
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:BLEURT-20
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... max_seq_length:512
# INFO:tensorflow:... vocab_file:None
# INFO:tensorflow:... do_lower_case:None
# INFO:tensorflow:... sp_model:sent_piece
# INFO:tensorflow:... dynamic_seq_length:True
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating SentencePiece tokenizer.
# INFO:tensorflow:Creating SentencePiece tokenizer.
# INFO:tensorflow:Will load model: BLEURT-20\sent_piece.model.
# INFO:tensorflow:SentencePiece tokenizer created.
# ...

# %%
# # Define folder paths
# reference_folder = "../results/Parkinson/en"
# hypothesis_folder = "../results/Parkinson/translation_fra_to_eng" 

# # Evaluate translations
# scores = evaluate_metrics_aggregated(reference_folder, hypothesis_folder)#, scorer)
# scores

# %%
# Define folder paths
reference_folder = "../results/Parkinson/en"
#hypothesis_folder = "../results/Parkinson/translation_fra_to_eng" 
hypothesis_folder = "../results/Parkinson/words_raw_translation"

# Evaluate translations
scores = evaluate_metrics_aggregated(reference_folder, hypothesis_folder, scorer)
scores
# Out:
# Number of sentences: 1797

# %%
scores
# Out:
# {'BLEU': BLEU = 63.57 76.8/66.0/59.3/54.3 (BP = 1.000 ratio = 1.019 hyp_len = 22245 ref_len = 21836),
#  'CHRF': chrF2 = 73.47,
#  'BLEURT': {'sentence_scores': [0.7197261452674866,
#    0.7229514718055725,
#    0.47905194759368896,
#    0.9701268076896667,
#    0.8641468286514282,
#    0.9357859492301941,
#    0.9810683131217957,
#    0.8458057045936584,
#    0.910040020942688,
#    0.7309941649436951,
#    1.006190299987793,
#    0.8456199765205383,
#    0.8697147965431213,
#    0.8670017123222351,
#    0.8344280123710632,
#    0.9597257971763611,
#    0.9890215992927551,
#    0.7539965510368347,
#    1.0008138418197632,
#    0.7885713577270508,
#    0.7994926571846008,
#    0.9381557106971741,
#    0.9957112073898315,
#    0.9117868542671204,
#    0.7876163721084595,
#    0.9124775528907776,
#    0.7233565449714661,
#    0.9479159116744995,
#    0.9958479404449463,
#    0.8650489449501038,
#    0.8569376468658447,
#    0.8289135694503784,
#    0.8299680352210999,
# ...

# %%
# Save scores to pickle
# with open('bleurt_scores.pkl', 'wb') as f:
#     pickle.dump(scores, f)
with open('bleurt_scores.pkl', 'rb') as f:
    belurts_scores = pickle.load(f)

# Calculate overall average BLEURT score
total_bleurt_sum = 0
total_sentence_count = 0

for file, metrics in belurts_scores.items():
    # Get sentence-level BLEURT scores
    sentence_scores = metrics['BLEURT']['sentence_scores']
    # Add the sum of scores to the total sum
    total_bleurt_sum += sum(sentence_scores)
    # Add the number of sentences to the total count
    total_sentence_count += len(sentence_scores)

# Calculate overall average
overall_bleurt_average = total_bleurt_sum / total_sentence_count

print(f"Overall BLEURT Average: {overall_bleurt_average:.4f}")
# Out:
# Overall BLEURT Average: 0.7971

# %%
# Define folder paths
reference_folder = "../results/Parkinson/en"
hypothesis_folder = "../results/Parkinson/translation_fra_to_eng"

# Evaluate translations
scores = evaluate_metric_by_filename(reference_folder, hypothesis_folder)#, scorer)
