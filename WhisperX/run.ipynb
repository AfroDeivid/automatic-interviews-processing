# %%
import whisperx
import gc 
import torch
import os

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# # Params

# %%
device = "cpu"  # Choose between "cpu" or "cuda"
batch_size = 16  # Reduce if low on GPU memory
compute_type = "int8"  # Use "int8" if low on GPU memory (may reduce accuracy) if not float16
folder = "OBE1"
audio = "Id 13.m4a"

# %% [markdown]
# # Run

# %%
# Define paths for data and audio
data_path = os.path.abspath(os.path.join("..", "data"))  # Absolute path to the data directory
audio_path = os.path.join(data_path, folder, audio)  # Full path to the audio file

output_dir = os.path.join("outputs", folder)  # Use the same structure as the input for output
os.makedirs(output_dir, exist_ok=True)
audio_id = os.path.splitext(os.path.join(folder, audio))[0].replace(" ", "_")  # Remove spaces and extension

# Hugging Face token for Pyannote (for diarization)
HF_TOKEN = "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"

# %%
# 1. Transcribe with original whisper (batched)

model = whisperx.load_model("large-v2",device, compute_type=compute_type, language = "en")
# save model to local path (optional)
#model_dir = "./models/"
#model = whisperx.load_model("large-v2", device, compute_type=compute_type, download_root=model_dir, language = "en")
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.3.3. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\david\.cache\torch\whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.0. Bad things might happen unless you revert torch to 1.x.

# %%
audio = whisperx.load_audio(audio_path)
transcript = model.transcribe(audio, batch_size=batch_size)
print(transcript["segments"]) # before alignment

# delete model if low on GPU resources
gc.collect(); torch.cuda.empty_cache(); del model
# Out:
# [{'text': " But yeah, from my experience, it wasn't just like calmness and serenity. There's also a bit of instability and uncertainty. I thought some of the questions were very interesting, like some of the words you used, like torment, like not knowing what's going to happen, uncertainty, I could relate to some of those things as well. You mean the last question there? The one I just completed, some of the words that were used were interesting, but I could relate to them a lot.", 'start': 0.009, 'end': 23.797}, {'text': " I guess it's like a fear of your own bodily sensations and your thoughts and like a fear of being overwhelmed by them and that it's too much and that it's something you won't be able to handle.", 'start': 25.725, 'end': 45.367}, {'text': " Seeing as this is something I don't practice a lot, you know, so like really tapping into like my bodily sensations and in a non-judgmental way and not being scared of them and really embracing them is like quite unfamiliar to me. So I definitely had that sensation for sure. If I'm recording, do you want me to do it now? Go for it. Yeah, absolutely, that's fine.", 'start': 45.367, 'end': 65.367}, {'text': " Overwhelmed by your body sensation, just the fact that you were actually taking time to listen to the sensation? It was just the intensity. It was just very, very intense. And I think I was like judging the experience as well, you know? Yeah, exactly, like something may go out of control or something, you know? Or that the sensation may be too intense that I wouldn't be able to like seize it, you know?", 'start': 67.142, 'end': 94.189}, {'text': " yeah it's just like a very you know it's like I guess it's like almost like a fear that the experience is going to be very very intense you know", 'start': 96.237, 'end': 109.121}, {'text': " And this was due to the VR setup, the environment? Yeah, this was due to the instructions that were given, you know, where he said, like, one of the moments he was saying, like, you know, really feel your hands, you know. So obviously not that, like, I didn't, you know, get any sort of, like, bad feelings, but that's just an example of, like, a period where it can get intense, you know.", 'start': 110.06, 'end': 133.66}, {'text': ' So it was more about the instruction than the setup itself, the VR? Oh no, that was very relaxing. It was just like the actual exercises I had to do.', 'start': 134.326, 'end': 144.48}, {'text': " I think it was more of that, yeah, it was just more sensations and being afraid that they're too intense, that they're too overwhelming, that I wouldn't be, that they could be too much for me and I wouldn't be able to come down to a baseline and find calmness, you know? Like this is something I never really do, so I guess that's why it's the case as well, you know?", 'start': 146.186, 'end': 167.056}, {'text': " Did you have the experience of mindfulness meditation before? Yes, I've done it a couple of times. It's not difficult, it's not hard for me to put it into practice and to be non-judgmental about it. I don't do it a lot.", 'start': 169.753, 'end': 189.155}, {'text': " Yeah, I have to say like in the experience like there was it was weird because it was like ups and downs there's periods where I was able to kind of like collect myself and kind of be calm again, but It would come and go but that wasn't That wasn't because of changes in my experience. So like what I saw and stuff because that was like more constant. It was always calm There was never there was never like anxiety that was prompted by what I saw or by what the guy said So like the variance was like because of me rather, you know Yeah", 'start': 189.428, 'end': 216.988}, {'text': " In the first part where you close your eyes, could you feel relaxed during that part? So this is when I saw the guy doing the whole thing? No, this is the part where you close your eyes and you're...", 'start': 221.715, 'end': 232.824}, {'text': " The forest. Yeah, what a ...

# %%
# 2. Align whisper output

model_a, metadata = whisperx.load_align_model(language_code=transcript["language"], device=device)
transcript_aligned = whisperx.align(transcript["segments"], model_a, metadata, audio, device, return_char_alignments=False)
print(transcript_aligned["segments"]) # after alignment

# delete model if low on GPU resources
gc.collect(); torch.cuda.empty_cache(); del model_a
# Out:
# [{'start': 0.269, 'end': 3.59, 'text': " But yeah, from my experience, it wasn't just like calmness and serenity.", 'words': [{'word': 'But', 'start': 0.269, 'end': 0.389, 'score': 0.403}, {'word': 'yeah,', 'start': 0.489, 'end': 0.769, 'score': 0.492}, {'word': 'from', 'start': 0.809, 'end': 1.049, 'score': 0.344}, {'word': 'my', 'start': 1.069, 'end': 1.209, 'score': 0.954}, {'word': 'experience,', 'start': 1.229, 'end': 1.59, 'score': 0.339}, {'word': 'it', 'start': 1.65, 'end': 1.73, 'score': 0.3}, {'word': "wasn't", 'start': 1.77, 'end': 2.03, 'score': 0.326}, {'word': 'just', 'start': 2.13, 'end': 2.39, 'score': 0.559}, {'word': 'like', 'start': 2.41, 'end': 2.55, 'score': 0.279}, {'word': 'calmness', 'start': 2.61, 'end': 3.05, 'score': 0.49}, {'word': 'and', 'start': 3.11, 'end': 3.23, 'score': 0.635}, {'word': 'serenity.', 'start': 3.25, 'end': 3.59, 'score': 0.283}]}, {'start': 4.531, 'end': 7.692, 'text': "There's also a bit of instability and uncertainty.", 'words': [{'word': "There's", 'start': 4.531, 'end': 4.771, 'score': 0.335}, {'word': 'also', 'start': 4.791, 'end': 4.971, 'score': 0.353}, {'word': 'a', 'start': 5.011, 'end': 5.031, 'score': 0.842}, {'word': 'bit', 'start': 5.071, 'end': 5.171, 'score': 0.321}, {'word': 'of', 'start': 5.191, 'end': 5.251, 'score': 0.394}, {'word': 'instability', 'start': 5.331, 'end': 5.991, 'score': 0.78}, {'word': 'and', 'start': 6.791, 'end': 6.911, 'score': 0.359}, {'word': 'uncertainty.', 'start': 6.971, 'end': 7.692, 'score': 0.747}]}, {'start': 8.712, 'end': 17.615, 'text': "I thought some of the questions were very interesting, like some of the words you used, like torment, like not knowing what's going to happen, uncertainty, I could relate to some of those things as well.", 'words': [{'word': 'I', 'start': 8.712, 'end': 8.772, 'score': 0.761}, {'word': 'thought', 'start': 8.792, 'end': 8.992, 'score': 0.848}, {'word': 'some', 'start': 9.112, 'end': 9.232, 'score': 0.538}, {'word': 'of', 'start': 9.252, 'end': 9.292, 'score': 0.007}, {'word': 'the', 'start': 9.312, 'end': 9.372, 'score': 0.894}, {'word': 'questions', 'start': 9.412, 'end': 9.752, 'score': 0.944}, {'word': 'were', 'start': 9.772, 'end': 10.032, 'score': 0.624}, {'word': 'very', 'start': 10.072, 'end': 10.232, 'score': 0.371}, {'word': 'interesting,', 'start': 10.453, 'end': 10.853, 'score': 0.399}, {'word': 'like', 'start': 10.873, 'end': 11.013, 'score': 0.286}, {'word': 'some', 'start': 11.033, 'end': 11.153, 'score': 0.239}, {'word': 'of', 'start': 11.173, 'end': 11.253, 'score': 0.256}, {'word': 'the', 'start': 11.273, 'end': 11.333, 'score': 0.018}, {'word': 'words', 'start': 11.373, 'end': 11.533, 'score': 0.46}, {'word': 'you', 'start': 11.573, 'end': 11.653, 'score': 0.152}, {'word': 'used,', 'start': 11.733, 'end': 11.833, 'score': 0.278}, {'word': 'like', 'start': 11.853, 'end': 11.993, 'score': 0.267}, {'word': 'torment,', 'start': 12.133, 'end': 12.813, 'score': 0.704}, {'word': 'like', 'start': 13.854, 'end': 14.074, 'score': 0.186}, {'word': 'not', 'start': 14.114, 'end': 14.314, 'score': 0.496}, {'word': 'knowing', 'start': 14.334, 'end': 14.554, 'score': 0.545}, {'word': "what's", 'start': 14.594, 'end': 14.754, 'score': 0.259}, {'word': 'going', 'start': 14.774, 'end': 14.874, 'score': 0.096}, {'word': 'to', 'start': 14.894, 'end': 14.954, 'score': 0.042}, {'word': 'happen,', 'start': 14.994, 'end': 15.334, 'score': 0.857}, {'word': 'uncertainty,', 'start': 15.394, 'end': 15.974, 'score': 0.66}, {'word': 'I', 'start': 15.994, 'end': 16.034, 'score': 0.241}, {'word': 'could', 'start': 16.094, 'end': 16.274, 'score': 0.204}, {'word': 'relate', 'start': 16.294, 'end': 16.535, 'score': 0.51}, {'word': 'to', 'start': 16.555, 'end': 16.595, 'score': 0.496}, {'word': 'some', 'start': 16.635, 'end': 16.755, 'score': 0.256}, {'word': 'of', 'start': 16.795, 'end': 16.895, 'score': 0.359}, {'word': 'those', 'start': 16.915, 'end': 17.095, 'score': 0.556}, {'word': 'things', 'start': 17.115, 'end ...

# %%
# 3. Assign speaker labels

diarize_model = whisperx.DiarizationPipeline(use_auth_token=HF_TOKEN, device=device)
# add min/max number of speakers if known
diarize_segments = diarize_model(audio,max_speakers=5) # min_speakers=2, num_speakers=3

# %%
result = whisperx.assign_word_speakers(diarize_segments, transcript_aligned)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs

#result["segments"]
# Out:
#                                segment label     speaker       start  \
# 0    [ 00:00:00.008 -->  00:00:23.522]     A  SPEAKER_02    0.008489
# 1    [ 00:00:07.920 -->  00:00:08.242]     B  SPEAKER_01    7.920204
# 2    [ 00:00:25.679 -->  00:00:33.998]     C  SPEAKER_01   25.679117
# 3    [ 00:00:32.928 -->  00:00:33.013]     D  SPEAKER_00   32.928693
# 4    [ 00:00:33.013 -->  00:00:33.064]     E  SPEAKER_02   33.013582
# ..                                 ...   ...         ...         ...
# 105  [ 00:06:59.719 -->  00:07:09.210]    DB  SPEAKER_00  419.719864
# 106  [ 00:07:05.322 -->  00:07:05.916]    DC  SPEAKER_02  425.322581
# 107  [ 00:07:10.144 -->  00:07:16.001]    DD  SPEAKER_02  430.144312
# 108  [ 00:07:16.001 -->  00:07:19.991]    DE  SPEAKER_01  436.001698
# 109  [ 00:07:18.599 -->  00:07:18.955]    DF  SPEAKER_02  438.599321
#
#             end  intersection       union
# 0     23.522920   -412.240080  435.894511
# 1      8.242784   -427.520216  427.982796
# 2     33.998302   -401.764698  410.223883
# 3     33.013582   -402.749418  402.974307
# 4     33.064516   -402.698484  402.889418
# ..          ...           ...         ...
# 105  429.210526     -6.552474   16.183136
# 106  425.916808     -9.846192   10.580419
# 107  436.001698      0.140000    5.857385
# 108  439.991511     -0.098698    4.228511
# 109  438.955857     -2.696321    3.192857
#
# [110 rows x 7 columns]
# [{'start': 0.269, 'end': 3.59, 'text': " But yeah, from my experience, it wasn't just like calmness and serenity.", 'words': [{'word': 'But', 'start': 0.269, 'end': 0.389, 'score': 0.403, 'speaker': 'SPEAKER_02'}, {'word': 'yeah,', 'start': 0.489, 'end': 0.769, 'score': 0.492, 'speaker': 'SPEAKER_02'}, {'word': 'from', 'start': 0.809, 'end': 1.049, 'score': 0.344, 'speaker': 'SPEAKER_02'}, {'word': 'my', 'start': 1.069, 'end': 1.209, 'score': 0.954, 'speaker': 'SPEAKER_02'}, {'word': 'experience,', 'start': 1.229, 'end': 1.59, 'score': 0.339, 'speaker': 'SPEAKER_02'}, {'word': 'it', 'start': 1.65, 'end': 1.73, 'score': 0.3, 'speaker': 'SPEAKER_02'}, {'word': "wasn't", 'start': 1.77, 'end': 2.03, 'score': 0.326, 'speaker': 'SPEAKER_02'}, {'word': 'just', 'start': 2.13, 'end': 2.39, 'score': 0.559, 'speaker': 'SPEAKER_02'}, {'word': 'like', 'start': 2.41, 'end': 2.55, 'score': 0.279, 'speaker': 'SPEAKER_02'}, {'word': 'calmness', 'start': 2.61, 'end': 3.05, 'score': 0.49, 'speaker': 'SPEAKER_02'}, {'word': 'and', 'start': 3.11, 'end': 3.23, 'score': 0.635, 'speaker': 'SPEAKER_02'}, {'word': 'serenity.', 'start': 3.25, 'end': 3.59, 'score': 0.283, 'speaker': 'SPEAKER_02'}], 'speaker': 'SPEAKER_02'}, {'start': 4.531, 'end': 7.692, 'text': "There's also a bit of instability and uncertainty.", 'words': [{'word': "There's", 'start': 4.531, 'end': 4.771, 'score': 0.335, 'speaker': 'SPEAKER_02'}, {'word': 'also', 'start': 4.791, 'end': 4.971, 'score': 0.353, 'speaker': 'SPEAKER_02'}, {'word': 'a', 'start': 5.011, 'end': 5.031, 'score': 0.842, 'speaker': 'SPEAKER_02'}, {'word': 'bit', 'start': 5.071, 'end': 5.171, 'score': 0.321, 'speaker': 'SPEAKER_02'}, {'word': 'of', 'start': 5.191, 'end': 5.251, 'score': 0.394, 'speaker': 'SPEAKER_02'}, {'word': 'instability', 'start': 5.331, 'end': 5.991, 'score': 0.78, 'speaker': 'SPEAKER_02'}, {'word': 'and', 'start': 6.791, 'end': 6.911, 'score': 0.359, 'speaker': 'SPEAKER_02'}, {'word': 'uncertainty.', 'start': 6.971, 'end': 7.692, 'score': 0.747, 'speaker': 'SPEAKER_02'}], 'speaker': 'SPEAKER_02'}, {'start': 8.712, 'end': 17.615, 'text': "I thought some of the questions were very interesting, like some of the words you used, like torment, like not knowing what's going to happen, uncertainty, I could relate to some of those things as well.", 'words': [{'word': 'I', 'start': 8.712, 'end': 8.772, 'score': 0.761, 'speaker': 'SPEAKER_02'}, {'word': 'thought', 'start': 8.792, 'end': 8.992, 'score': 0.848, 'speaker': 'SPEAKER_02'}, {'word': 'some', 'start': 9.112, 'end': 9.232, 'score': 0.538, 'speaker': 'SPEAKER_02'}, {'word': 'of', 'start': 9.252, 'end': 9.292, 'score': 0.007, 'speaker': 'SPEAKER_02'}, {'word': 'the', 'start': 9.312, 'end': 9.372, 'score': 0.894, 'speaker': 'SPEAKER_02'}, {'word': 'questions', 'start': 9.412, 'end': 9.752, 'score': 0.944, 'speaker': 'SPEAKER_02'}, {'word': 'were', 'start': 9.772, 'end': 10.032, 'score': 0.624, 'speaker': 'SPEAKER_02'}, {'word': 'very', 'start': 10.072, 'end': 10.232, 'score': 0.371, 'speaker': 'SPEAKER_02'}, {'word': 'interesting,', 'start': 10.453, 'end': 10.853, 'score': 0.399, 'speaker': 'SPEAKER_02'}, {'word': 'like', 'start': 10.873, 'end': 11.013, 'score': 0.286, 'speaker': 'SPEAKER_02'}, {'word': 'some', 'start': 11.033, 'end': 11.153, 'score': 0.239, 'speaker': 'SPEAKER_02'}, {'word': 'of', 'start': 11.173, 'end': 11.253, 'score': 0.256, 'speaker': 'SPEAKER_02'}, {'word': 'the', 'start': 11.273, 'end': 11.333, 'score': 0.018, 'speaker': 'SPEAKER_02'}, {'word': 'words', 'start': 11.373, 'end': 11.533, 'score': 0.46, 'speaker': 'SPEAKER_02'}, {'word': 'you', 'start': 11.573, 'end': 11.653, 'score': 0.152, 'speaker': 'SPEAKER_02'}, {'word': 'used,', 'start': 11.733, 'end': 11.833, 'score': 0.278, 'speaker': 'SPEAKER_02'}, {'word': 'like', 'start': 11.853, 'end': 11.993, 'score': 0.267, 'speaker': 'SPEAKER_02'}, {'word': 'torment,', 'start': 12.133, 'end': 12.813, 'score': 0.704, 'speaker': 'SPEAKER_02'}, {'word': 'like', 'start': 13.854, 'end' ...

# %%
with open(f"results\{audio_id}_str.txt", "w") as file:
    # Iterate through each segment in result["segments"]
    for segment in result["segments"]:
        # Extract text and speaker information
        text = segment["text"]
        speaker = segment["speaker"]
        
        # Write the text and speaker information to the file
        file.write(f"Speaker: {speaker}\nText: {text}\n\n")

# %%
with open(f"results\{audio_id}_merged.txt", "w") as file:
    # Initialize variables to keep track of the current speaker and their dialogue
    current_speaker = None
    current_dialogue = ""
    
    # Iterate through each segment in result["segments"]
    for segment in result["segments"]:
        speaker = segment["speaker"]
        text = segment["text"]
        
        # If the current segment's speaker is the same as the previous one, append the text
        if speaker == current_speaker:
            current_dialogue += " " + text
        else:
            # If the current segment's speaker is different, write the previous speaker's dialogue to the file
            if current_speaker is not None:
                file.write(f"{current_speaker}: {current_dialogue}\n\n")
            
            # Update the current speaker and dialogue
            current_speaker = speaker
            current_dialogue = text
    
    # Write the last speaker's dialogue to the file
    if current_speaker is not None:
        file.write(f"{current_speaker}: {current_dialogue}\n\n")
